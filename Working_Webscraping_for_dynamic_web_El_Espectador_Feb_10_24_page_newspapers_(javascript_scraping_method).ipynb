# %% [markdown]
# <a href="https://colab.research.google.com/github/jairzinhos/WebScraping/blob/main/Working_Webscraping_for_dynamic_web_El_Espectador_Feb_10_24_page_newspapers_(javascript_scraping_method).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Webscraping using simple tools in python (not sophisticated libraries). Take care of the structure of the sites so as to change the configuration as desired.
#
# Premmiun content for 'El Espectador' Using the basic tools we can scrape a difficult dynamic web structure. It's so important to analyze the structure of the web page we trying to scrape Analyzing html and javascript format into it so as to do a good job. We need basic tools like BeautifulSoup, requests, and json Url used: "https://www.elespectador.com/economia/la-reforma-pensional-empieza-a-caminar-en-que-va-la-discusion/"
#
# This method is carried with common scraping tools as Beautiful because of the dynamic website does not disguise the content but it is showed on the source code. The trouble surges when we want to extract the content from a javiscript part, this procedure is different to others with html language. Here we need to extract the javascript part where the desired content is, and then become it into json format in order to get the information. Finally we transform the json data into a big list we can navigate through so as to have our content in the desired format.

# %%
url= input(f'Please enter the complete url address of the article')
# Out:
# Please enter the complete url address of the articlehttps://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/

# %%
import requests

# %%
r1 = requests.get(url)
coverpage = r1.content

# %%
import json
import re

# %%
from bs4 import BeautifulSoup

# %%
soup1 = BeautifulSoup(coverpage, 'html5lib')

# %%
#We get a soup with the information needed, however we must identify the key html part where is placed our wanted data.
type(soup1)
# Out:
# bs4.BeautifulSoup

# %%
#This part concerns the html part we are looking for, but we'll have some troubles into it, because we'll find a javascript structure containing our goal data
coverpage_news = soup1.find('script', id="fusion-metadata", type="application/javascript")
coverpage_news
# Out:
# <script id="fusion-metadata" type="application/javascript">window.Fusion=window.Fusion||{};Fusion.arcSite="el-espectador";Fusion.contextPath="/pf";Fusion.deployment="823";Fusion.globalContent={"_id":"WLM6Z7OD2NDDJKBGS6BAHOKWAE","content_elements":[{"_id":"Q46ZZ6YW6NHTDIUWRXUMV4ISXU","additional_properties":{"_id":1707508276774,"comments":[],"inline_comments":[]},"content":"Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.","type":"text"},{"_id":"X4TI25ETKZFMFFPYO6QIXH6KII","additional_properties":{"countryId":48,"fullSizeResizeUrl":"/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","galleries":[],"iptc_source":"Digital Vision","iptc_title":"Contributor","keywords":["competition","determination","growth","success","the way forward"],"mime_type":"image/jpeg","originalName":"27_pag4,ph01_20210826072153.jpg","originalUrl":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","proxyUrl":"/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","published":true,"resizeUrl":"/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","restricted":false,"takenOn":"2011-01-23T00:00:00Z","thumbnailResizeUrl":"/resizer/2e5Z4KHQ-mqau22PpJLPcwxrN5w=/300x0/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","usage_instructions":"Not Released (NR)","version":1,"_id":"43SBW53RUFEBZBYWUTX4SGGYTI","comments":[]},"address":{"locality":"Kyoto","region":"Kyoto"},"alt_text":"Not Released (NR)","auth":{"1":"5d679834e292fc8ff869cc85c30ad9c0df4948933915fd414e673ea8bdd25a14"},"copyright":"Yagi Studio","created_date":"2021-08-27T00:21:55Z","credits":{"affiliation":[{"name":"Getty Images","type":"author"}],"by":[{"name":"Yagi Studio","type":"author"}]},"height":531,"last_updated_date":"2021-08-27T00:21:55Z","licensable":false,"owner":{"id":"elespectador"},"slug":"110946664","source":{"additional_properties":{"editor":"photo center"},"edit_url":"","system":"photo center"},"subtitle":"¿Cómo está el clima para invertir en dólares?","taxonomy":{},"type":"image","url":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","version":"0.10.9","width":800,"country_name":"Colombia","caption":"En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images","cropImages":{"425":"https://www.elespectador.com/resizer/3CKpccCRlF6vS1UUInIKcCBPc0s=/393x261/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","600":"https://www.elespectador.com/resizer/ahiZg9HZM-aAB2I-roOkoBbH8e8=/568x378/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","1199":"https://www.elespectador.com/resizer/SNbovcj8sRIRm9IaT-v-o9mvTYw=/1110x739/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","1200":"https://www.elespectador.com/resizer/csnE3Xh3YSOOPgZPLyU7OKx9INs=/920x613/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg"}},{"_id":"YWLHZ5OQUBBVBO4QYMWQMPGFOU","additional_properties":{"_id":1707508276776,"comments":[],"inline_comments":[]},"content":"Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.","type":"text"},{"_id":"7GAPXMESPBCP5DP5YB7NRDAPX4","additional_properties":{"_id":1707670224908,"comments":[],"inline_comments":[]},"content":"Siguiendo esta línea, vale p ...

# %%
# Identifying the Javascript, there is no way to navigate into it. We have to change our strategy
coverpage_news.string
# Out:
# 'window.Fusion=window.Fusion||{};Fusion.arcSite="el-espectador";Fusion.contextPath="/pf";Fusion.deployment="823";Fusion.globalContent={"_id":"WLM6Z7OD2NDDJKBGS6BAHOKWAE","content_elements":[{"_id":"Q46ZZ6YW6NHTDIUWRXUMV4ISXU","additional_properties":{"_id":1707508276774,"comments":[],"inline_comments":[]},"content":"Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.","type":"text"},{"_id":"X4TI25ETKZFMFFPYO6QIXH6KII","additional_properties":{"countryId":48,"fullSizeResizeUrl":"/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","galleries":[],"iptc_source":"Digital Vision","iptc_title":"Contributor","keywords":["competition","determination","growth","success","the way forward"],"mime_type":"image/jpeg","originalName":"27_pag4,ph01_20210826072153.jpg","originalUrl":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","proxyUrl":"/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","published":true,"resizeUrl":"/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","restricted":false,"takenOn":"2011-01-23T00:00:00Z","thumbnailResizeUrl":"/resizer/2e5Z4KHQ-mqau22PpJLPcwxrN5w=/300x0/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","usage_instructions":"Not Released (NR)","version":1,"_id":"43SBW53RUFEBZBYWUTX4SGGYTI","comments":[]},"address":{"locality":"Kyoto","region":"Kyoto"},"alt_text":"Not Released (NR)","auth":{"1":"5d679834e292fc8ff869cc85c30ad9c0df4948933915fd414e673ea8bdd25a14"},"copyright":"Yagi Studio","created_date":"2021-08-27T00:21:55Z","credits":{"affiliation":[{"name":"Getty Images","type":"author"}],"by":[{"name":"Yagi Studio","type":"author"}]},"height":531,"last_updated_date":"2021-08-27T00:21:55Z","licensable":false,"owner":{"id":"elespectador"},"slug":"110946664","source":{"additional_properties":{"editor":"photo center"},"edit_url":"","system":"photo center"},"subtitle":"¿Cómo está el clima para invertir en dólares?","taxonomy":{},"type":"image","url":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","version":"0.10.9","width":800,"country_name":"Colombia","caption":"En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images","cropImages":{"425":"https://www.elespectador.com/resizer/3CKpccCRlF6vS1UUInIKcCBPc0s=/393x261/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","600":"https://www.elespectador.com/resizer/ahiZg9HZM-aAB2I-roOkoBbH8e8=/568x378/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","1199":"https://www.elespectador.com/resizer/SNbovcj8sRIRm9IaT-v-o9mvTYw=/1110x739/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg","1200":"https://www.elespectador.com/resizer/csnE3Xh3YSOOPgZPLyU7OKx9INs=/920x613/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg"}},{"_id":"YWLHZ5OQUBBVBO4QYMWQMPGFOU","additional_properties":{"_id":1707508276776,"comments":[],"inline_comments":[]},"content":"Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.","type":"text"},{"_id":"7GAPXMESPBCP5DP5YB7NRDAPX4","additional_properties":{"_id":1707670224908,"comments":[],"inline_comments":[]},"content":"Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda ...

# %%
coverpage_newsString = coverpage_news.string

# %% [markdown]
# Here we have a relevant function that was obtained from "https://scrapfly.io/blog/how-to-scrape-hidden-web-data/", it's so useful because the main trouble was trying to parse the javascript part where was embedded the date we were trying to extract. This function made possible to become javascript code into json format making the extraction of content throughout json navigation. The central aspect after was knowing the pattern that follows the data inside the json format in rder to extract it systematically and an ordered way.

# %%
import json


def find_json_objects(text: str, decoder=json.JSONDecoder()):
    """Find JSON objects in text, and generate decoded JSON data"""
    pos = 0
    while True:
        match = text.find("{", pos)
        if match == -1:
            break
        try:
            result, index = decoder.raw_decode(text[match:])
            yield result
            pos = match + index
        except ValueError:
            pos = match + 1

# %%
print(list(find_json_objects(coverpage_newsString)))
# Out:
# [{}, {'_id': 'WLM6Z7OD2NDDJKBGS6BAHOKWAE', 'content_elements': [{'_id': 'Q46ZZ6YW6NHTDIUWRXUMV4ISXU', 'additional_properties': {'_id': 1707508276774, 'comments': [], 'inline_comments': []}, 'content': 'Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.', 'type': 'text'}, {'_id': 'X4TI25ETKZFMFFPYO6QIXH6KII', 'additional_properties': {'countryId': 48, 'fullSizeResizeUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', 'galleries': [], 'iptc_source': 'Digital Vision', 'iptc_title': 'Contributor', 'keywords': ['competition', 'determination', 'growth', 'success', 'the way forward'], 'mime_type': 'image/jpeg', 'originalName': '27_pag4,ph01_20210826072153.jpg', 'originalUrl': 'https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', 'proxyUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', 'published': True, 'resizeUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', 'restricted': False, 'takenOn': '2011-01-23T00:00:00Z', 'thumbnailResizeUrl': '/resizer/2e5Z4KHQ-mqau22PpJLPcwxrN5w=/300x0/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', 'usage_instructions': 'Not Released (NR)', 'version': 1, '_id': '43SBW53RUFEBZBYWUTX4SGGYTI', 'comments': []}, 'address': {'locality': 'Kyoto', 'region': 'Kyoto'}, 'alt_text': 'Not Released (NR)', 'auth': {'1': '5d679834e292fc8ff869cc85c30ad9c0df4948933915fd414e673ea8bdd25a14'}, 'copyright': 'Yagi Studio', 'created_date': '2021-08-27T00:21:55Z', 'credits': {'affiliation': [{'name': 'Getty Images', 'type': 'author'}], 'by': [{'name': 'Yagi Studio', 'type': 'author'}]}, 'height': 531, 'last_updated_date': '2021-08-27T00:21:55Z', 'licensable': False, 'owner': {'id': 'elespectador'}, 'slug': '110946664', 'source': {'additional_properties': {'editor': 'photo center'}, 'edit_url': '', 'system': 'photo center'}, 'subtitle': '¿Cómo está el clima para invertir en dólares?', 'taxonomy': {}, 'type': 'image', 'url': 'https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', 'version': '0.10.9', 'width': 800, 'country_name': 'Colombia', 'caption': 'En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images', 'cropImages': {'425': 'https://www.elespectador.com/resizer/3CKpccCRlF6vS1UUInIKcCBPc0s=/393x261/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', '600': 'https://www.elespectador.com/resizer/ahiZg9HZM-aAB2I-roOkoBbH8e8=/568x378/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', '1199': 'https://www.elespectador.com/resizer/SNbovcj8sRIRm9IaT-v-o9mvTYw=/1110x739/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg', '1200': 'https://www.elespectador.com/resizer/csnE3Xh3YSOOPgZPLyU7OKx9INs=/920x613/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg'}}, {'_id': 'YWLHZ5OQUBBVBO4QYMWQMPGFOU', 'additional_properties': {'_id': 1707508276776, 'comments': [], 'inline_comments': []}, 'content': 'Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.', 'type': 'text'}, {'_id': '7GAPXMESPBCP5DP5YB7NRDAPX4', 'additional_properties': {'_id': 1707670224908, 'comments': [], 'inline_comments': []}, 'content': 'Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar ...

# %%
find_json_objects(coverpage_newsString)
# Out:
# <generator object find_json_objects at 0x7d59ee0fa9d0>

# %%
# Creating a list with the result got by find_json function to easily navigate into it
listCoverpageNewsString = list(find_json_objects(coverpage_newsString))
listCoverpageNewsString
# Out:
# [{},
#  {'_id': 'WLM6Z7OD2NDDJKBGS6BAHOKWAE',
#   'content_elements': [{'_id': 'Q46ZZ6YW6NHTDIUWRXUMV4ISXU',
#     'additional_properties': {'_id': 1707508276774,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.',
#     'type': 'text'},
#    {'_id': 'X4TI25ETKZFMFFPYO6QIXH6KII',
#     'additional_properties': {'countryId': 48,
#      'fullSizeResizeUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'galleries': [],
#      'iptc_source': 'Digital Vision',
#      'iptc_title': 'Contributor',
#      'keywords': ['competition',
#       'determination',
#       'growth',
#       'success',
#       'the way forward'],
#      'mime_type': 'image/jpeg',
#      'originalName': '27_pag4,ph01_20210826072153.jpg',
#      'originalUrl': 'https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'proxyUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'published': True,
#      'resizeUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'restricted': False,
#      'takenOn': '2011-01-23T00:00:00Z',
#      'thumbnailResizeUrl': '/resizer/2e5Z4KHQ-mqau22PpJLPcwxrN5w=/300x0/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'usage_instructions': 'Not Released (NR)',
#      'version': 1,
#      '_id': '43SBW53RUFEBZBYWUTX4SGGYTI',
#      'comments': []},
#     'address': {'locality': 'Kyoto', 'region': 'Kyoto'},
#     'alt_text': 'Not Released (NR)',
#     'auth': {'1': '5d679834e292fc8ff869cc85c30ad9c0df4948933915fd414e673ea8bdd25a14'},
#     'copyright': 'Yagi Studio',
#     'created_date': '2021-08-27T00:21:55Z',
#     'credits': {'affiliation': [{'name': 'Getty Images', 'type': 'author'}],
#      'by': [{'name': 'Yagi Studio', 'type': 'author'}]},
#     'height': 531,
#     'last_updated_date': '2021-08-27T00:21:55Z',
#     'licensable': False,
#     'owner': {'id': 'elespectador'},
#     'slug': '110946664',
#     'source': {'additional_properties': {'editor': 'photo center'},
#      'edit_url': '',
#      'system': 'photo center'},
#     'subtitle': '¿Cómo está el clima para invertir en dólares?',
#     'taxonomy': {},
#     'type': 'image',
#     'url': 'https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#     'version': '0.10.9',
#     'width': 800,
#     'country_name': 'Colombia',
#     'caption': 'En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images',
#     'cropImages': {'425': 'https://www.elespectador.com/resizer/3CKpccCRlF6vS1UUInIKcCBPc0s=/393x261/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      '600': 'https://www.elespectador.com/resizer/ahiZg9HZM-aAB2I-roOkoBbH8e8=/568x378/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      '1199': 'https://www.elespectador.com/resizer/SNbovcj8sRIRm9IaT-v-o9mvTYw=/1110x739/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      '1200': 'https://www.elespectador.com/resizer/csnE3Xh3YSOOPgZPLyU7OKx9INs=/920x613/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg'}},
#    {'_id': 'YWLHZ5OQUBBVBO4QYMWQMPGFOU',
#     'additional_properties': {'_id': 1707508276776,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.',
#     'type': 'text'},
#    {'_id': '7GAPXMESPBCP5DP5YB7NRDAPX4',
#     'additional_properties': {'_id': 1707670224908,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024.',
#     'type': 'text'},
#    {'_id': 'A66DFNQNENGOLIY4KH7MFSIKDM',
#     'additional_properties': {'_id': 1707508276792,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/finanzas-personales/es-buen-momento-para-endeudarse-asi-estan-los-creditos-en-2024-noticias-colombia/" target="_blank"><i><b>¿Es buen momento para endeudarse?: así está el panorama del crédito en 2024</b></i></a>',
#     'type': 'text'},
#    {'_id': '6TXELYNCDBB7HKGFVFZ7JMV4F4',
#     'additional_properties': {'_id': 1707508276778,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Al mirar en el retrovisor, lejos ha quedado ya aquel temido noviembre de 2022, cuando el dólar subió más allá del umbral de los $5.000, desatando un frenesí de compra en el que muchas personas se agolparon en las taquillas de las casas de cambio por el temor a que el billete verde se siguiera encumbrando hasta aplastar al peso colombiano y, de paso, la capacidad adquisitiva de miles de consumidores. Hoy, muchos se sonrojan al recordar este episodio.',
#     'type': 'text'},
#    {'_id': 'ZAEAUKP3VVFEBALEBZU62537FQ',
#     'additional_properties': {'_id': 1707508276780,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Pero allá, donde el horizonte se pierde, está un 2014 donde el dólar valía $2.000. Días que no volverán, especialmente tras una pandemia, una espiral inflacionaria generalizada y una desaceleración económica global.',
#     'type': 'text'},
#    {'_id': 'DSQU75OGNBHBLL4GGYFLAM3RZA',
#     'additional_properties': {'_id': 1707508276781,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Sin ir más lejos, de un año hacia acá la tasa de cambio del dólar ha caído más o menos unos $1.000 y en lo corrido de 2024 la divisa ha transcurrido entre mínimos de <b>$3.889 y máximos de $3.975 </b>en su Tasa Representativa del Mercado (TRM).',
#     'type': 'text'},
#    {'_id': 'AEBDIX6T2RF6ZA6BKFARP2H6ZE',
#     'additional_properties': {'_id': 'JLXPJ3FIVVDFLCR5TPGH36MXYY',
#      'comments': []},
#     'content': '<iframe title="Tasa Representativa del Mercado en 2023" aria-label="Interactive line chart" id="datawrapper-chart-b0ujw" src="https://datawrapper.dwcdn.net/b0ujw/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();\r\n</script>\r\n',
#     'type': 'raw_html'},
#    {'_id': '2OFZFZUZ6FAIRBAFLJJ2CQKHDI',
#     'additional_properties': {'_id': 1707508276783,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Varios analistas coinciden en que el arranque del año ha estado marcado por una inusitada estabilidad en la moneda estadounidense, después de un par de años donde nos acostumbró a la volatilidad.',
#     'type': 'text'},
#    {'_id': '5OR2SIMGSVCI5EO27JXEMSG6KI',
#     'additional_properties': {'_id': 1707508276784,
#      'comments': [],
#      'inline_comments': []},
#     'content': '“Los movimientos en lo corrido de 2024 lo que están haciendo es consolidar la tasa de cambio en unos niveles más estables y sostenibles y se espera que esto siga así”, explica <b>Sergio Olarte</b>, economista principal de Scotiabank Colpatria.',
#     'type': 'text'},
#    {'_id': 'WZTRBUD6GVET5G3VRM5CVBOYLE',
#     'additional_properties': {'_id': 1707670224917,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>Lea también: </b><a href="https://www.elespectador.com/economia/super-bowl-publicidad-y-economia-como-el-evento-es-una-maquina-de-hacer-dinero/" target="_blank"><b>Super Bowl, publicidad y economía: cómo el evento es una máquina de hacer dinero</b></a>',
#     'type': 'text'},
#    {'_id': 'JSEFL6DWP5BKPGWN7V6RWZR7YQ',
#     'additional_properties': {'_id': 1707508276785,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'No obstante, Olarte advierte que la volatilidad de la moneda se incrementó en las últimas semanas, con cambios de $20 de un día para otro a cambios de $50 y hasta $100. Esto, entre otras cosas, por recientes comentarios de firmas calificadoras de riesgo (como S&amp;P Global Ratings) acerca de la economía colombiana.',
#     'type': 'text'},
#    {'_id': 'FPSE4UZYXRAPBCHPHQIKEL44X4',
#     'additional_properties': {'_id': 'Q7AOAXBPUZF3XLH3DZRDRSIKTY',
#      'comments': []},
#     'content': '<iframe title="TRM en 2024" aria-label="Interactive line chart" id="datawrapper-chart-mm185" src="https://datawrapper.dwcdn.net/mm185/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();\r\n</script>\r\n',
#     'type': 'raw_html'},
#    {'_id': 'FITYCTMP6NCV7GR3XQVCZQVTU4',
#     'additional_properties': {'_id': 1707508276787,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Dentro de las proyecciones para la tasa de cambio, los analistas estiman un dólar más barato al cierre del primer trimestre del año. Un factor a tener en cuenta si está planeando comprar divisas ahora. Sin embargo, las propias proyecciones del Gobierno en su Plan Financiero establecen que la tasa de cambio se ubicará por encima de los $4.000 para terminar 2024.',
#     'type': 'text'},
#    {'_id': 'ZDNWKQJKTVFQLLWGFNZ7W76AXE',
#     'additional_properties': {'_id': 1707670224921,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>Lea también: </b><a href="https://www.elespectador.com/economia/las-alarmas-en-el-plan-financiero-2024-del-gobierno-segun-anif-noticias-colombia/" target="_blank"><b>Las alarmas que enciende el Plan Financiero 2024 del Gobierno</b></a>',
#     'type': 'text'},
#    {'_id': 'LXKL35K555AUNFEY2LI7W2CJZY',
#     'additional_properties': {'_id': 1707670224922,
#      'comments': [],
#      'inline_comments': []},
#     'content': '¿Es buen momento para invertir en dólares?',
#     'level': 2,
#     'type': 'header'},
#    {'_id': 'LXGXYK26ORDCPKHSDLE572ZHRU',
#     'additional_properties': {'_id': 1707508276788,
#      'comments': [],
#      'inline_comments': []},
#     'content': '“El dólar puede bajar un poco más al cierre del primer trimestre e, incluso, más en el segundo trimestre del año, atendiendo a que la inflación está controlada en Estados Unidos, se acerca a la meta del 2 %, y la Reserva Federal disminuirá su tasa de interés este año. Esto hará que el mercado estadounidense sea menos atractivo para invertir y los inversionistas buscarán economías emergentes, como la nuestra, donde los intereses han venido bajando, pero siguen siendo altos para la región”, explica <b>Sebastián Chacón</b>, director de la Escuela de Negocios y Desarrollo Internacional del Politécnico Grancolombiano.',
#     'type': 'text'},
#    {'_id': 'LRHSZJBTSFFQFA2IKPMWV7RZ5Y',
#     'additional_properties': {'_id': 1707508276789,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'En la misma línea, <b>Felipe Campos</b>, gerente de Estrategia e Inversión de Alianza Fiduciaria, explica que monedas como las de Colombia o México han resistido bien los incrementos en el dólar a comparación del resto de la región, de ahí que permanezcan con relativa poca volatilidad.',
#     'type': 'text'},
#    {'_id': 'CUI5LLO3QVBDPPQPB3SHVTEX6U',
#     'additional_properties': {'_id': 1707508276790,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Para el experto en inversiones, el dólar tendría presiones bajistas en el corto plazo, por ejemplo, el dato de inflación en Estados Unidos para enero de 2024 (que se conocerá en los próximos días).',
#     'type': 'text'},
#    {'_id': 'NO7VJTOJBNBPLG3HZ6MXYFHEDM',
#     'additional_properties': {'_id': 1707670224926,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>Lea también: </b><a href="https://www.elespectador.com/economia/armando-benedetti-a-la-fao-le-sirve-a-colombia-tener-nuevo-embajador-en-la-organizacion/" target="_blank"><b>Benedetti a la FAO: ¿le sirve a Colombia tener nuevo embajador en la organización?</b></a>',
#     'type': 'text'},
#    {'_id': 'DPT6JOMYOJBGBIE23NSMIUT6UQ',
#     'additional_properties': {'_id': 1707508276791,
#      'comments': [],
#      'inline_comments': []},
#     'content': '“Y si el dólar baja más, nos gustaría comprarlo en ese momento porque el resto del año va a ser movido. Se vienen los trámites de las reformas en Colombia, antes de junio, y luego las elecciones en Estados Unidos”, indica Campos.',
#     'type': 'text'},
#    {'_id': 'SRQJ2PXVSFFE7I7HZPQQ5I2D4U',
#     'additional_properties': {'_id': 1707508276793,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'El primer consejo al invertir es que se debe hacerlo cuando esa acción, esa criptomoneda, ese gramo de oro o el activo que le llame la atención (el dólar en este caso) esté bajando de precio.',
#     'type': 'text'},
#    {'_id': 'HBM2CFQMZNCXDEQET6OE5CGH5I',
#     'additional_properties': {'_id': 1707508276794,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Así las cosas, puede que sea muy pronto para apostarle a una divisa que, como indican los pronósticos, podría ser más barata al cabo de algunas semanas. Si tiene un viaje al exterior o una compra internacional en mente, quizá le convenga esperar unas semanas para comprar dólares.',
#     'type': 'text'},
#    {'_id': 'S3A37B3NUJGZDN372B2L5B6KTE',
#     'additional_properties': {'_id': 1707670224930,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Dicho esto, siempre es clave mencionar que el mundo gira y gira y estas proyecciones bien pueden verse alteradas de un día para otro debido a eventos globales que le pegan a una serie de factores económicos (hablamos de eventos como guerras, pandemias, inestabilidad política...). No hay una respuesta única, certera y a prueba de coyunturas acerca del precio del dólar, en últimas.',
#     'type': 'text'},
#    {'_id': 'YSCBQIM2QRFPBFF2F3AMDEX27Q',
#     'additional_properties': {'_id': 1707508276795,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>¿El dólar ya no es buen negocio?</b>',
#     'level': 2,
#     'type': 'header'},
#    {'_id': 'LZWM7XBJRBBYZPEA4LG52YRM4M',
#     'additional_properties': {'_id': 1707508276796,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Por décadas, la compra de dólares era el vehículo al cual se subían quienes querían ganarse unos pesos aprovechando la tasa de cambio, resguardarse de la inflación confiando en una moneda más fuerte que la nuestra o construir un patrimonio sin aventurarse en las turbulencias de la bolsa de valores.',
#     'type': 'text'},
#    {'_id': 'EFOFKATIPVESXLSDHG7UVXKXY4',
#     'additional_properties': {'_id': 1707508276797,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Esto ha venido cambiando y la compra de dólares en sí misma (es decir, cambiar pesos por su equivalente en divisa americana) ha perdido algo de su atractivo para 2024.',
#     'type': 'text'},
#    {'_id': 'KLKCBZ2WTBEE7EZKZODNDAUIDU',
#     'additional_properties': {'_id': 1707508276798,
#      'comments': [],
#      'inline_comments': []},
#     'content': '“En 2022, la compra de dólares enriqueció a muchos. La divisa estuvo en niveles bajos durante una parte del año, hasta que la incertidumbre económica -un factor clave aquí- fue llevándola a precios tan altos como los $5.200. Ahora, el escenario es bastante distinto: nuestra inflación viene bajando, la Fed ha dicho que bajará tasas en algún momento del año y, en general, hay un mercado de certidumbre donde no se esperan movimientos bruscos de la tasa de cambio”, asevera <b>Henry Amorocho</b>, profesor de Hacienda Pública y Presupuesto de la Universidad del Rosario.',
#     'type': 'text'},
#    {'_id': 'D3KAFTUWKZBO7CXFRUIILC2E5U',
#     'additional_properties': {'_id': 1707508276799,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/macroeconomia/la-inflacion-arranca-2024-bajando-en-enero-y-acumula-10-meses-de-descensos-continuos/" target="_blank"><i><b>La inflación arranca 2024 bajando y acumula 10 meses de descensos continuos</b></i></a>',
#     'type': 'text'},
#    {'_id': 'AJS36R4EAJDI7AFPNT7M5O6HKY',
#     'additional_properties': {'_id': 1707508276800,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Dicen los analistas que los dólares (y cualquier divisa) son buen negocio cuando hay grandes “espacios cambiarios”, es decir, amplias distancias entre el precio actual del dólar y el que tendría en el futuro. Lo cierto es que esta franja, a día de hoy, es pequeña, así como las ganancias que tendría un inversionista.',
#     'type': 'text'},
#    {'_id': 'TXP4OJ3QGRB7VMAZTQNNUMSXOI',
#     'additional_properties': {'_id': 1707508276801,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Por ejemplo, la mayoría de los analistas económicos consultados por el Banco de la República en enero pasado previó una Tasa Representativa del Mercado (TRM) entre los <b>$3.839 y $3.939</b> durante 2024. Así mismo, los más recientes pronósticos de Fedesarrollo indican que la TRM no será mayor a <b>$4.025</b> a diciembre de 2024.',
#     'type': 'text'},
#    {'_id': 'BW6VLJY5DJAJ7FZXDURXHDPJFU',
#     'additional_properties': {'_id': 1707508276802,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Con un dólar a <b>$3.922</b> al cierre del pasado 9 de febrero, la eventual valorización de una inversión en dólares en 2024 -bajo un escenario sin sorpresas- podría no ser suficientemente jugosa para algunos inversionistas.',
#     'type': 'text'},
#    {'_id': 'EPAUAMPGUFHU3L4TNVRCUNKIQE',
#     'additional_properties': {'_id': 1707508276803,
#      'comments': [],
#      'inline_comments': []},
#     'content': '“Creemos que el dólar está cambiando de tendencia después de 12 años. Ya no consideramos que vaya a tener un gran valor en el largo plazo, pero sigue siendo un activo importante para diversificar, porque si a Colombia le va mal, al dólar le va bien. Entonces siempre se debe tener algo en dólar”, aconseja el gerente de Estrategia e Inversión de Alianza Fiduciaria.',
#     'type': 'text'},
#    {'_id': '3KWLSIMUL5ECDL4TIPT22PIT6I',
#     'additional_properties': {'_id': 1707508276804,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'En esto coincide <b>Michael Ortegón</b>, decano de la Facultad de Ciencias Económicas y Administrativas de UNINPAHU, quien explica que la compra de dólares solo debe hacerse para hacer inversiones que agregarán más valor en el largo plazo.',
#     'type': 'text'},
#    {'_id': '5IEFQVD4IJDTDPWUPO6HZMFQLE',
#     'additional_properties': {'_id': 1707508276805,
#      'comments': [],
#      'inline_comments': []},
#     'content': '“El dólar no se debe usar como medio de cambio o para “ahorrarlo” en cuentas de ahorro que no ganan ningún interés por estar depositados. En cualquier caso, la moneda estadounidense estará por encima del peso colombiano, pero eso no implica que sea buena idea comprar dólares”, agrega el académico.',
#     'type': 'text'},
#    {'_id': 'D24W4NBEIZEE3EWS2XVFSZQJAA',
#     'additional_properties': {'_id': 1707508276806,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Se suele recomendar que entre un 20 % a un 30 % de los ahorros de una persona estén tasados en una moneda extranjera (como el dólar), ya sea en algún fondo de inversión o en cuentas tasadas en divisas, las cuales son ofrecidas por la mayoría de los bancos en Colombia. Eso sí, estos productos están destinados a depósitos por encima de los $30 millones.',
#     'type': 'text'},
#    {'_id': 'W56LLPXHXFHILJHHMLHK5RQT2U',
#     'additional_properties': {'_id': 1707508276807,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>Activos en dólares</b>',
#     'level': 2,
#     'type': 'header'},
#    {'_id': 'DEVHNYFDSVFILNVDUCCY27ZOJY',
#     'additional_properties': {'_id': 1707508276808,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Si apostarles a los billetes verdes (por sí solos) no es tan recomendable en este momento, el panorama es muy distinto para los activos tasados en dólares, tales como las acciones, los bonos del Tesoro o los inmuebles.',
#     'type': 'text'},
#    {'_id': 'QXKFZGMSPZC6ZCIGNQYD5YWIGU',
#     'additional_properties': {'_id': 1707508276809,
#      'comments': [],
#      'inline_comments': []},
#     'content': '“El activo en dólares que mejor le está yendo son las acciones de empresas estadounidenses, que están disparadas y están teniendo mucho mejor retorno que el resto de acciones en el mundo, gracias a los resultados de las empresas de tecnología”, afirma Felipe Campos.',
#     'type': 'text'},
#    {'_id': 'WWRIMCMWY5FM7EJNEDC6YP2KNE',
#     'additional_properties': {'_id': 1707508276810,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'En esto coincide el decano de UNINPAHU, quien resalta que “ciertos activos valuados en dólares muestran un desempeño positivo, destacándose las acciones tecnológicas de empresas líderes como Apple, Microsoft y Amazon. Además, el mercado inmobiliario se mantiene sólido (debido a las tasas de interés altas), con propiedades residenciales y comerciales conservando su valor; mientras que el oro, considerado a menudo como un refugio seguro, ha experimentado un aumento en su precio”.',
#     'type': 'text'},
#    {'_id': 'AX6A56QSBZACXGZLV3Q4CPJPEI',
#     'additional_properties': {'_id': 1707508276811,
#      'comments': [],
#      'inline_comments': []},
#     'content': '<b>Puede interesarle:</b><a href="https://www.elespectador.com/economia/la-reserva-federal-bajara-las-tasas-de-interes-en-estados-unidos/" target="_blank"><b> </b><i><b>¿Tasas de interés más bajas en EE.UU.?: sí, pero no tan rápido</b></i></a>',
#     'type': 'text'},
#    {'_id': 'HCFGNAR3FBG4VPEVYTMX6NVBKM',
#     'additional_properties': {'_id': 1707508276812,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Finalmente, Olarte, el economista principal de Scotiabank Colpatria destaca que “se podría pensar en acciones en Estados Unidos que podrían seguir valorizándose o alguna inversión inmobiliaria que salga más o menos rentable (…). Los activos que están teniendo un buen momento son alguna parte de las acciones en Estados Unidos, porque se espera que las tasas de interés bajen y eso puede ayudar a que la parte bursátil del mundo se mejore”.',
#     'type': 'text'},
#    {'_id': 'W6M2RFW2OVEWTLH77Q6D45QLVE',
#     'additional_properties': {'_id': 1707508276813,
#      'comments': [],
#      'inline_comments': []},
#     'content': 'Tenga en cuenta que si va a invertir en activos de alto riesgo, como la renta variable (acciones), lo mejor es asesorarse con profesionales. En materia de dólar, el mejor consejo en este momento es actuar con prudencia. Lo que indican los analistas es que parece no ser el mejor momento para vender casa, carro o invertir sus ahorros en una moneda que, parece, podría no dar los mejores resultados.',
#     'type': 'text'},
#    {'_id': 'UAL4XW7JCFAJJCSISUT3YLQONA',
#     'additional_properties': {'_id': 1707508276814,
#      'comments': [],
#      'inline_comments': []},
#     'content': '💰📈💱 <b>¿Ya te enteraste de las últimas noticias </b><a href="https://www.elespectador.com/economia"><b>económicas</b></a><b>? </b>Te invitamos a verlas en <a href="https://www.elespectador.com/economia/">El Espectador</a>.',
#     'type': 'text'}],
#   'created_date': '2024-02-09T19:35:26.892Z',
#   'last_updated_date': '2024-02-12T12:00:01.509Z',
#   'canonical_url': '/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/',
#   'headlines': {'basic': 'Comprar dólares: ¿cómo están las aguas para invertir en la divisa?',
#    'meta_title': 'Comprar dólares: ¿cómo están las aguas para invertir en la divisa? | Noticias Colombia',
#    'mobile': '',
#    'native': '',
#    'print': '',
#    'tablet': '',
#    'web': ''},
#   'description': {'basic': 'Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos.'},
#   'taxonomy': {'primary_section': {'_id': '/economia/finanzas-personales',
#     '_website': 'el-espectador',
#     'type': 'section',
#     'version': '0.6.0',
#     'name': 'Finanzas personales',
#     'description': 'Últimas noticias de subsidios y finanzas personales en Colombia. Noticias del SOAT para motos y carros, pensiones, impuestos, precio del dólar hoy, hambre cero, familias en acción, devolución del iva, Colombia Mayor, cómo hacer la declaración de renta, información sobre las cesantías en El Espectador.',
#     'path': '/economia/finanzas-personales',
#     'parent_id': '/economia',
#     'parent': {'default': '/economia'},
#     'additional_properties': {'original': {'_id': '/economia/finanzas-personales',
#       'social': {'rss': None,
#        'twitter': None,
#        'facebook': None,
#        'instagram': None},
#       'site': {'site_keywords': 'Finanzas personales, economia personas, gastos personales, consejos de gasto personal, consejos de inversion, como invertir, economia,economia en colombia, colombia economia',
#        'pagebuilder_path_for_native_apps': None,
#        'site_title': 'Finanzas personales: ahorro, subsidios e impuestos',
#        'site_tagline': None,
#        'site_description': 'Últimas noticias de subsidios y finanzas personales en Colombia. Noticias del SOAT para motos y carros, pensiones, impuestos, precio del dólar hoy, hambre cero, familias en acción, devolución del iva, Colombia Mayor, cómo hacer la declaración de renta, información sobre las cesantías en El Espectador.',
#        'site_url': None,
#        'site_about': None},
#       'site_topper': {'site_logo_image': None},
#       'navigation': {'nav_title': None},
#       '_admin': {'alias_ids': ['/economia/finanzas-personales']},
#       '_website': 'el-espectador',
#       'name': 'Finanzas personales',
#       'order': {'treeCallBySection': 1031,
#        'default': 2001,
#        'burgerMenuRedesign': 2001,
#        'footerRedesign': 2003,
#        'BurgerMenuV2': 3001},
#       'parent': {'default': '/economia',
#        'burgerMenuRedesign': '/economia',
#        'mainNavRedesign': None,
#        'footerRedesign': '/economia',
#        'treeCallBySection': '/',
#        'trendNavComplete': None,
#        'searcherNavBar': None,
#        'BurgerMenuV2': '/economia'},
#       'ancestors': {'default': ['/economia'],
#        'burgerMenuRedesign': ['/economia'],
#        'mainNavRedesign': [],
#        'footerRedesign': ['/economia'],
#        'treeCallBySection': ['/'],
#        'trendNavComplete': [],
#        'searcherNavBar': [],
#        'BurgerMenuV2': ['/', '/noticias', '/economia']},
#       'inactive': False,
#       'node_type': 'section'}}},
#    'tags': [{'description': 'Dólar', 'slug': 'dolar', 'text': 'Dólar'},
#     {'description': 'Inversión', 'slug': 'inversion', 'text': 'Inversión'},
#     {'description': 'Tasas de interés',
#      'slug': 'tasas-de-interes',
#      'text': 'Tasas de interés'},
#     {'description': 'Inflación en Colombia',
#      'slug': 'inflacion-en-colombia',
#      'text': 'Inflación en Colombia'},
#     {'description': 'Finanzas personales',
#      'slug': 'finanzas-personales',
#      'text': 'Finanzas personales'},
#     {'description': 'PremiumEE, etiqueta para manejo de contenido exclusivo',
#      'slug': 'premiumee',
#      'text': 'PremiumEE'},
#     {'description': 'invertir en dólares',
#      'slug': 'invertir-en-dolares',
#      'text': 'invertir en dólares'},
#     {'description': 'Inversionistas',
#      'slug': 'inversionistas',
#      'text': 'Inversionistas'}],
#    'sections': [{'_id': '/economia/finanzas-personales',
#      '_website': 'el-espectador',
#      'type': 'section',
#      'version': '0.6.0',
#      'name': 'Finanzas personales',
#      'description': 'Últimas noticias de subsidios y finanzas personales en Colombia. Noticias del SOAT para motos y carros, pensiones, impuestos, precio del dólar hoy, hambre cero, familias en acción, devolución del iva, Colombia Mayor, cómo hacer la declaración de renta, información sobre las cesantías en El Espectador.',
#      'path': '/economia/finanzas-personales',
#      'parent_id': '/economia',
#      'parent': {'default': '/economia'},
#      'additional_properties': {'original': {'_id': '/economia/finanzas-personales',
#        'social': {'rss': None,
#         'twitter': None,
#         'facebook': None,
#         'instagram': None},
#        'site': {'site_keywords': 'Finanzas personales, economia personas, gastos personales, consejos de gasto personal, consejos de inversion, como invertir, economia,economia en colombia, colombia economia',
#         'pagebuilder_path_for_native_apps': None,
#         'site_title': 'Finanzas personales: ahorro, subsidios e impuestos',
#         'site_tagline': None,
#         'site_description': 'Últimas noticias de subsidios y finanzas personales en Colombia. Noticias del SOAT para motos y carros, pensiones, impuestos, precio del dólar hoy, hambre cero, familias en acción, devolución del iva, Colombia Mayor, cómo hacer la declaración de renta, información sobre las cesantías en El Espectador.',
#         'site_url': None,
#         'site_about': None},
#        'site_topper': {'site_logo_image': None},
#        'navigation': {'nav_title': None},
#        '_admin': {'alias_ids': ['/economia/finanzas-personales']},
#        '_website': 'el-espectador',
#        'name': 'Finanzas personales',
#        'order': {'treeCallBySection': 1031,
#         'default': 2001,
#         'burgerMenuRedesign': 2001,
#         'footerRedesign': 2003,
#         'BurgerMenuV2': 3001},
#        'parent': {'default': '/economia',
#         'burgerMenuRedesign': '/economia',
#         'mainNavRedesign': None,
#         'footerRedesign': '/economia',
#         'treeCallBySection': '/',
#         'trendNavComplete': None,
#         'searcherNavBar': None,
#         'BurgerMenuV2': '/economia'},
#        'ancestors': {'default': ['/economia'],
#         'burgerMenuRedesign': ['/economia'],
#         'mainNavRedesign': [],
#         'footerRedesign': ['/economia'],
#         'treeCallBySection': ['/'],
#         'trendNavComplete': [],
#         'searcherNavBar': [],
#         'BurgerMenuV2': ['/', '/noticias', '/economia']},
#        'inactive': False,
#        'node_type': 'section'}},
#      '_website_section_id': 'el-espectador./economia/finanzas-personales'},
#     {'_id': '/economia',
#      '_website': 'el-espectador',
#      'type': 'section',
#      'version': '0.6.0',
#      'name': 'Economía',
#      'description': 'Encuentre aquí las últimas noticias económicas de Colombia y del mundo. TRM y dólar del día y principales indicadores económicos y los hechos más relevantes en economía y negocios. Noticias económicas a hoy.',
#      'path': '/economia',
#      'parent_id': '/',
#      'parent': {'default': '/'},
#      'additional_properties': {'original': {'_id': '/economia',
#        'social': {'rss': None,
#         'twitter': None,
#         'facebook': None,
#         'instagram': None},
#        'site': {'site_keywords': 'noticias economicas, economía de Colombia, indicadores economicos, finanzas, bancos, economia global, noticias económicas de Colombia, noticias económicas internacionales.',
#         'pagebuilder_path_for_native_apps': None,
#         'site_title': 'Últimas noticias económicas de Colombia y el mundo',
#         'site_tagline': None,
#         'site_description': 'Encuentre aquí las últimas noticias económicas de Colombia y del mundo. TRM y dólar del día y principales indicadores económicos y los hechos más relevantes en economía y negocios. Noticias económicas a hoy.',
#         'site_url': None,
#         'site_about': None},
#        'site_topper': {'site_logo_image': None},
#        'navigation': {'nav_title': None},
#        'name': 'Economía',
#        '_website': 'el-espectador',
#        'parent': {'default': '/',
#         'footerSections': None,
#         'MainNav': None,
#         'BurgerMenu': None,
#         'burgerMenuRedesign': '/',
#         'mainNavRedesign': '/',
#         'footerRedesign': '/',
#         'treeCallBySection': '/',
#         'trendNav': '/',
#         'trendNavComplete': '/',
#         'searcherNavBar': '/',
#         'BurgerMenuV2': '/noticias'},
#        'ancestors': {'default': [],
#         'footerSections': [],
#         'MainNav': [],
#         'BurgerMenu': [],
#         'burgerMenuRedesign': [],
#         'mainNavRedesign': ['/'],
#         'footerRedesign': [],
#         'treeCallBySection': ['/'],
#         'trendNav': ['/'],
#         'trendNavComplete': [],
#         'searcherNavBar': ['/'],
#         'BurgerMenuV2': ['/', '/noticias']},
#        '_admin': {'alias_ids': ['/economia']},
#        'inactive': False,
#        'node_type': 'section',
#        'order': {'default': 1020,
#         'burgerMenuRedesign': 1011,
#         'treeCallBySection': 1061,
#         'mainNavRedesign': 1005,
#         'trendNav': 1007,
#         'footerRedesign': 1012,
#         'trendNavComplete': 1005,
#         'searcherNavBar': 1021,
#         'BurgerMenuV2': 2004}}},
#      '_website_section_id': 'el-espectador./economia'}],
#    'seo_keywords': ['Noticias económicas',
#     'comprar dolares',
#     'invertir en dolares',
#     'dolar a peso colombiano',
#     'dolar febrero 2024',
#     'inversion',
#     'consejos para invertir',
#     'consejos para invertir en dolares',
#     'dolar en Colombia',
#     'donde comprar dolares',
#     'inversion en Colombia',
#     'en que invertir 2024']},
#   'promo_items': {'basic': {'_id': 'X4TI25ETKZFMFFPYO6QIXH6KII',
#     'additional_properties': {'countryId': 48,
#      'fullSizeResizeUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'galleries': [],
#      'iptc_source': 'Digital Vision',
#      'iptc_title': 'Contributor',
#      'keywords': ['competition',
#       'determination',
#       'growth',
#       'success',
#       'the way forward'],
#      'mime_type': 'image/jpeg',
#      'originalName': '27_pag4,ph01_20210826072153.jpg',
#      'originalUrl': 'https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'proxyUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'published': True,
#      'resizeUrl': '/resizer/2kgjLYxm4zUAegVZHyXFTsqSOIs=/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'restricted': False,
#      'takenOn': '2011-01-23T00:00:00Z',
#      'thumbnailResizeUrl': '/resizer/2e5Z4KHQ-mqau22PpJLPcwxrN5w=/300x0/arc-anglerfish-arc2-prod-elespectador/public/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#      'usage_instructions': 'Not Released (NR)',
#      'version': 1},
#     'address': {'locality': 'Kyoto', 'region': 'Kyoto'},
#     'alt_text': 'Not Released (NR)',
#     'auth': {'1': '5d679834e292fc8ff869cc85c30ad9c0df4948933915fd414e673ea8bdd25a14'},
#     'copyright': 'Yagi Studio',
#     'created_date': '2021-08-27T00:21:55Z',
#     'credits': {'affiliation': [{'name': 'Getty Images', 'type': 'author'}],
#      'by': [{'name': 'Yagi Studio', 'type': 'author'}]},
#     'height': 531,
#     'last_updated_date': '2021-08-27T00:21:55Z',
#     'licensable': False,
#     'owner': {'id': 'elespectador'},
#     'slug': '110946664',
#     'source': {'additional_properties': {'editor': 'photo center'},
#      'edit_url': '',
#      'system': 'photo center'},
#     'subtitle': '¿Cómo está el clima para invertir en dólares?',
#     'taxonomy': {},
#     'type': 'image',
#     'url': 'https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg',
#     'version': '0.10.9',
#     'width': 800,
#     'country_name': 'Colombia',
#     'caption': 'En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images'}},
#   'display_date': '2024-02-12T12:00:00Z',
#   'credits': {'by': [{'_id': 'daniel-felipe-rodriguez-rincon',
#      'type': 'author',
#      'version': '0.5.8',
#      'name': 'Daniel Felipe Rodríguez Rincón ',
#      'image': {'url': 'https://s3.amazonaws.com/arc-authors/elespectador/bf4fa90c-f6b4-4348-97e4-580a0db709e2.png',
#       'version': '0.5.8'},
#      'description': 'Comunicador Social y Periodista. Desde 2017, se ha desempeñado en diferentes medios de comunicación colombianos.',
#      'url': '',
#      'slug': '',
#      'social_links': [{'site': 'email', 'url': 'drodriguez@elespectador.com'},
#       {'site': 'twitter', 'url': '@DanfeRodriguez'}],
#      'socialLinks': [{'site': 'email',
#        'url': 'drodriguez@elespectador.com',
#        'deprecated': True,
#        'deprecation_msg': 'Please use social_links.'},
#       {'site': 'twitter',
#        'url': '@DanfeRodriguez',
#        'deprecated': True,
#        'deprecation_msg': 'Please use social_links.'}],
#      'additional_properties': {'original': {'_id': 'daniel-felipe-rodriguez-rincon',
#        'firstName': 'Daniel Felipe',
#        'lastName': 'Rodríguez Rincón ',
#        'byline': 'Daniel Felipe Rodríguez Rincón ',
#        'role': 'Periodista',
#        'image': 'https://s3.amazonaws.com/arc-authors/elespectador/bf4fa90c-f6b4-4348-97e4-580a0db709e2.png',
#        'email': 'drodriguez@elespectador.com',
#        'affiliations': '',
#        'education': [],
#        'awards': [],
#        'books': [],
#        'podcasts': [],
#        'twitter': '@DanfeRodriguez',
#        'bio_page': '',
#        'bio': 'Comunicador Social y Periodista. Desde 2017, se ha desempeñado en diferentes medios de comunicación colombianos.',
#        'longBio': 'Comunicador Social y Periodista. Desde 2017, se ha desempeñado en diferentes medios de comunicación colombianos. En la actualidad, cubre el acontecer económico nacional, la disrupción tecnológica, las historias de sostenibilidad y la generación de desarrollo.',
#        'slug': '',
#        'native_app_rendering': False,
#        'fuzzy_match': False,
#        'contributor': False,
#        'status': True,
#        'expertise': 'Periodista de Economía y Tecnología ',
#        'last_updated_date': '2023-03-09T20:39:52.716Z'}},
#      'cropImages': {'1200': 'https://www.elespectador.com/resizer/LX021D97Sc0V0wfZfVWbzxj-B_Y=/140x140/filters:quality(60):format(jpeg)/s3.amazonaws.com/arc-authors/elespectador/bf4fa90c-f6b4-4348-97e4-580a0db709e2.png'}}]},
#   'subtype': 'article',
#   'publish_date': '2024-02-12T12:00:01.509Z',
#   'website_url': '/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/',
#   'type': 'story',
#   'related_content': {'basic': [], 'redirect': []},
#   'source': {'name': 'elespectador',
#    'source_type': 'staff',
#    'system': 'composer'},
#   'revision': {'branch': 'default',
#    'editions': ['default'],
#    'parent_id': 'BN7J5MBD5JEXHGYR5D4K4ZI2WM',
#    'published': True,
#    'revision_id': 'Y2NJOXZE7BDV7NTGT5WH2TMPII',
#    'user_id': 'drodriguez@elespectador.com'},
#   'label': {'contenido_exclusivo': {'display': True, 'text': 'Si', 'url': ''}},
#   'first_publish_date': '2024-02-11T19:31:38.701Z',
#   'subheadlines': {'basic': ''},
#   'planning': {'budget_line': 'Desarrollo'},
#   'metaImage': {'1200': 'https://www.elespectador.com/resizer/_USflWlKEX9yGRyMCX72DFxCfro=/657x0/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg'}},
#  {'source': 'story',
#   'query': {'uri': '/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/',
#    'arc-site': 'el-espectador'}},
#  {'ril': {'{"user":{}}': {'data': {'message': 'No user',
#      '_id': 'b4831fa62bde690661eb933f00f39b1350b03ef879b02469acab26003ed00227'},
#     'expires': 1707741217929,
#     'lastModified': 1707741097929}},
#   'aliados': {'{"contenido_patrocinado":{"offset":0,"section":"/contenido-patrocinado","size":5}}': {'data': {'cursos': [{'titulo': 'Maestría Universitaria en Marketing y Publicidad Digital',
#        'body': 'Metodología 100% virtual',
#        'url': 'https://www.emagister.com.co/cursolanding/?idBusqueda=2783921&sid=3&pfichas=14591&utm_source=elespectador&utm_medium=cpl&utm_content=widget1_pestana_cursos&utm_campaign=marketing_nebrija',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/g46mN2jwQoDXOAMfOzMyDrWWKG8=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/PUBLICIDAD.png',
#         '259x173': 'https://www.elespectador.com/resizer/3a4EvDbceHr11OVaZpvOZTWB_WE=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/PUBLICIDAD.png'}},
#       {'titulo': 'Maestría en Educación',
#        'body': 'Clases virtuales con servicio de consultas',
#        'url': 'https://www.emagister.com.co/cursolanding/?idBusqueda=2592225&sid=3&pfichas=14592&utm_source=elespectador&utm_medium=cpl&utm_content=widget2_pestana_cursos&utm_campaign=educacion_ibero',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/yETesHbDzUi6D3aScOizViQNi7E=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/EDUCACION.png',
#         '259x173': 'https://www.elespectador.com/resizer/gU62WTajcBOC_IxN_c3MRZWeH6E=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/EDUCACION.png'}},
#       {'titulo': 'Directorio de Centros Formativos',
#        'body': 'Ver los más recomendados por Emagister',
#        'url': 'https://cursos.elespectador.com',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/nhr8qjlJ1PsldrM0s1KT6sfOeqo=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/DIRECTORIO.png',
#         '259x173': 'https://www.elespectador.com/resizer/AvOUDNzd5r6uyUSKYOYVZulC5qE=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/DIRECTORIO.png'}},
#       {'titulo': 'Maestría en Supply Chain Management & Logistics',
#        'body': 'Presencial en Madrid, España',
#        'url': 'https://www.emagister.com.co/cursolanding?idBusqueda=2819633&pfichas=14594&sid=3&utm_source=elespectador&utm_medium=cpl&utm_content=widget4_pestana_cursos&utm_campaign=logistica_eae',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/4lxWtMeqDZciGOoupa7uXOeF8hI=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/LOGISTICA.png',
#         '259x173': 'https://www.elespectador.com/resizer/qKlF2BLtRu-vxRTJcPxcGGQm7IM=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/LOGISTICA.png'}},
#       {'titulo': 'Maestría en Psicología de la Intervención Social y Comunitaria',
#        'body': 'Metodología 100% virtual',
#        'url': 'https://www.emagister.com.co/cursolanding?idBusqueda=2820392&pfichas=26886&sid=3&utm_source=elespectador&utm_medium=cpl&utm_content=widget5_pestana_cursos&utm_campaign=psicologia_viu',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/z4U4Ou3YiFFCreSxxVgUqL39hHs=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/w3_home_programas_psicologia_ee.png',
#         '259x173': 'https://www.elespectador.com/resizer/Hygr0pdieJR5PS_n299nW-4EKHA=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/w3_home_programas_psicologia_ee.png'}},
#       {'titulo': 'Maestría Universitaria en Liderazgo y Dirección de Recursos Humanos',
#        'body': 'Metodología 100% virtual',
#        'url': 'https://www.emagister.com.co/cursolanding?idBusqueda=2787757&pfichas=26887&sid=3&utm_source=elespectador&utm_medium=cpl&utm_content=widget6_pestana_cursos&utm_campaign=rrhh_nebrija',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/rsmW4s2yymVDDo5ShAUoQLPJQCQ=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/FEBRERO_RRHH.png',
#         '259x173': 'https://www.elespectador.com/resizer/9SUvy4OZB5ZxTwwOqO61SbaZ3Es=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/FEBRERO_RRHH.png'}}],
#      'centros': [{'titulo': 'Especialización en Alta Gerencia',
#        'body': 'Metodología 100% virtual',
#        'url': 'https://www.emagister.com.co/cursolanding/?idBusqueda=2786718&sid=3&pfichas=14595&utm_source=elespectador&utm_medium=cpl&utm_content=widget1_pestana_centros&utm_campaign=alta_gerencia_ibero',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/4-ZgvhziyNFgGvy-U5A3EY3Y5Ws=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/FEBRERO_FINANZAS.png',
#         '259x173': 'https://www.elespectador.com/resizer/J_y8pPdg34gzs55GNNj4we1jmMI=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/FEBRERO_FINANZAS.png'}},
#       {'titulo': 'MBA en Español',
#        'body': 'Presencial en Madrid, España',
#        'url': 'https://www.emagister.com.co/cursolanding/?idBusqueda=2819639&sid=3&pfichas=14596&utm_source=elespectador&utm_medium=cpl&utm_content=widget2_pestana_centros&utm_campaign=mba_eae',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/RAFv9_UjHC71k3EBBdNzlg8kAxI=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/INNOVACION.png',
#         '259x173': 'https://www.elespectador.com/resizer/1nZF15lMrYHgOg0eYYzx1btHfnc=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/INNOVACION.png'}},
#       {'titulo': 'Maestría Universitaria en Nutrición y Salud',
#        'body': 'Metodología 100% virtual',
#        'url': 'https://www.emagister.com.co/cursolanding/?idBusqueda=2820356&sid=3&pfichas=14597&utm_source=elespectador&utm_medium=cpl&utm_content=widget3_pestana_centros&utm_campaign=nutricion_viu',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/kBNSezAn7OhYiZCG2UYfAQLwRrs=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/mktg_digital_C5.png',
#         '259x173': 'https://www.elespectador.com/resizer/E7wQmi3Q1zdfIsCJx0cxgkLjVSU=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/mktg_digital_C5.png'}},
#       {'titulo': 'Maestría Universitaria en Dirección y Organización de Proyectos',
#        'body': 'Metodología 100% virtual',
#        'url': 'https://www.emagister.com.co/cursolanding/?idBusqueda=2812447&sid=3&pfichas=26888&sid=3&utm_source=elespectador&utm_medium=cpl&utm_content=widget5_pestana_centros&utm_campaign=big_data_ibero',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/1lImUyUipKKeRVfBSlRAw13ZxRQ=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/mktg_digital2.png',
#         '259x173': 'https://www.elespectador.com/resizer/eHV77KFoPWr4OfIn53lrwnHhK3Y=/259x173/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/mktg_digital2.png'}},
#       {'titulo': 'Especialización en Analítica y Big Data',
#        'body': 'Metodología 100% virtual',
#        'url': 'https://www.emagister.com.co/cursolanding/?idBusqueda=2812447&sid=3&pfichas=26888&sid=3&utm_source=elespectador&utm_medium=cpl&utm_content=widget5_pestana_centros&utm_campaign=big_data_ibero',
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/Fw16WRyXqAtsaxGqW-iyB_Nbik0=/393x280/filters:quality(60):format(jpeg)/content.emagistercdn.com/elespectador/project_management2.png',
# ...
#        'created_at': '2022-07-21T15:58:03.254Z',
#        'updated_at': '2023-07-31T19:09:26.307Z',
#        'published': True,
#        'imagen': {'393x280': 'https://www.elespectador.com/resizer/-3KIAJTd8Tt74qWHqz9ddDRa54Y=/393x280/filters:quality(60):format(jpeg)/d2zajjwhe6xaiy.cloudfront.net/uploads/store_choose/store_chose_image/97/10_Lili_Pink_Mesa_de_trabajo_1.png',
#         '259x173': 'https://www.elespectador.com/resizer/r7X6-BS4uNfztHK1DOYDVn1TzaQ=/259x173/filters:quality(60):format(jpeg)/d2zajjwhe6xaiy.cloudfront.net/uploads/store_choose/store_chose_image/97/10_Lili_Pink_Mesa_de_trabajo_1.png'}}],
#      '_id': '76fc4211ea678f94766cfa91f6bd28f2fa25e7047ca4fd3f475ce1df82ce88bd'},
#     'expires': 1707741310582,
#     'lastModified': 1707741010127}}},
#  {},
#  {'collection': 'layouts',
#   'type': 'ContainerNoAds',
#   'props': {'collection': 'layouts',
#    'type': 'ContainerNoAds',
#    'id': 'ContainerNoAds',
#    'childProps': [{'collection': 'sections', 'id': 0},
#     {'collection': 'sections', 'id': 1},
#     {'collection': 'sections', 'id': 2},
#     {'collection': 'sections', 'id': 3},
#     {'collection': 'sections', 'id': 4},
#     {'collection': 'sections', 'id': 5},
#     {'collection': 'sections', 'id': 6}]},
#   'children': [{'collection': 'sections',
#     'props': {'collection': 'sections', 'id': 0},
#     'children': [{'collection': 'features',
#       'type': 'global/Header',
#       'props': {'collection': 'features',
#        'type': 'global/Header',
#        'id': 'f0fo43S1oavR8yG',
#        'name': 'headerarticulo',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {'bannerData': {'Autos': '/resizer/fGfT5mFivof9YsisLhRh3Pfr8G0=/arc-anglerfish-arc2-sandbox-sandbox-elespectador/public/FTVVCWTA4BFCFNLNZE4263EYRU.jpg',
#          'Autos Mobile': '/resizer/zCInfqdOgMsiP57lw_t99hbF8mE=/arc-anglerfish-arc2-sandbox-sandbox-elespectador/public/M7XLVUHJ6BHEDE4Q7S6L2PBICI.jpg',
#          'Autos Rule': '/autos',
#          'Turismo Mobile': '/resizer/3aaDIhTUUjAZqnn03K9lzWZprjg=/arc-anglerfish-arc2-prod-elespectador/public/MRADSQ43URH4JLSNUMPNANQF54.png',
#          'Turismo Rule': '/turismo/',
#          'Cultura': '/resizer/Io6qzHEMrAvmRdOnctLzEYOaIKQ=/arc-anglerfish-arc2-sandbox-sandbox-elespectador/public/WY7LYUYOXFGFBJKTEICP4BLG5U.jpg',
#          'Cultura Mobile': '/resizer/WGunMpAoGvTmAH7G7LklomZtP_8=/arc-anglerfish-arc2-sandbox-sandbox-elespectador/public/D7BOMEQ23NE35IICD3JWF4URSY.jpg',
#          'Cultura Rule': '/el-magazin-cultural',
#          'Colombia2020': '/resizer/6WXxZx1AT6PweEBTFs218xJM6Co=/arc-anglerfish-arc2-prod-elespectador/public/VYPO3CVD35G5NJDX5AKVWJEAD4.jpg',
#          'Colombia2020 Mobile': '/resizer/cPxZOiZhqSKbxf864emr05ADh8c=/arc-anglerfish-arc2-prod-elespectador/public/ERP4E2JAJRE2TDM5REE4Z5U75E.jpg',
#          'Colombia2020 Rule': '/colombia-20',
#          'Autos Link': '/autos/',
#          'Vea Link': '/revista-vea/',
#          'Turismo Link': '/turismo/',
#          'Cultura Link': '/el-magazin-cultural/',
#          'Colombia2020 Link': '/colombia-20/',
#          'impactomujer': '/resizer/cRGyaCp7F91oskQX3hJdOb67MxE=/arc-anglerfish-arc2-prod-elespectador/public/JZAFSGAV3BFPRKBCLYN2UNQ4TI.jpg',
#          'impactomujer Mobile': '/resizer/0PutHu4IV6D0uVoS0Mq_6UXAwf4=/arc-anglerfish-arc2-prod-elespectador/public/NVAHIUH2MVCC7P4DWRVXZDWAWA.jpg',
#          'impactomujer Rule': '/impacto-mujer',
#          'impactomujer Link': '/impacto-mujer/',
#          'Gastronomia Rule': '/gastronomia-y-recetas',
#          'Gastronomia': '/resizer/hxUmIisqbbwGMFFxhHI9qZEsTpY=/arc-anglerfish-arc2-prod-elespectador/public/UQJOOP525ZEWRHQO5IKOWMZDAY.png',
#          'Gastronomia Mobile': '/resizer/8QejGgbcN5e-3pq2lxwgZ7YFvQk=/arc-anglerfish-arc2-prod-elespectador/public/K5QNMIB2TRDRBA5D2LAGGXVJKM.png',
#          'Carrito': '/resizer/qERHAKnk7rSs4P6y7p3qDA7HvYY=/arc-anglerfish-arc2-prod-elespectador/public/VF3Q4MJMKFBPBFJI4ISSEJOMVE.jpg',
#          'Carrito Mobile': '/resizer/Zt4bey4COL07rSyz4O1op3TIvrI=/arc-anglerfish-arc2-prod-elespectador/public/YO6XS65OS5FGDH5BKFOYC6MJLU.jpg',
#          'Carrito Rule': '/el-carrito',
#          'Carrito Link': '/el-carrito/',
#          'Red Zoocial Rule': '/la-red-zoocial/',
#          'Red Zoocial': '/resizer/9HwJYrsXH40SQ886yRrZxEb_D8U=/arc-anglerfish-arc2-prod-elespectador/public/5GR2Z2FFCRBWPB3KITBXTTTESA.jpg',
#          'Red Zoocial Mobile': '/resizer/xUN9Mj9A76E6Veo5B_2LEYijKb8=/arc-anglerfish-arc2-prod-elespectador/public/AWQNX76PGJGUBEX2FIRTMQUCWY.jpg',
#          'Perros Rule': '/la-red-zoocial/perros/',
#          'Perros': '/resizer/CZnXT72P9wJioujCi6GucaWfKrA=/arc-anglerfish-arc2-prod-elespectador/public/YALVNUWPPVA2TOYKSNVLCGLKYM.jpg',
#          'Perros Mobile': '/resizer/NlwNAncUw1ONMKUUSeigOuQA8Dw=/arc-anglerfish-arc2-prod-elespectador/public/IDFHRANT35B7ZLZTMFYCNZYDUM.jpg',
#          'Gatos Rule': '/la-red-zoocial/gatos/',
#          'Gatos': '/resizer/yQu_i1vEO1-PHwesgq-1R0Hyxos=/arc-anglerfish-arc2-prod-elespectador/public/L7DZ2EGDX5FW5BYL2BUQQFXZ7A.jpg',
#          'Gatos Mobile': '/resizer/n4lvrLRCr-JmN6kgXtFAx2MgvWo=/arc-anglerfish-arc2-prod-elespectador/public/BISMBKWBKBEEXAMRIQZSC64RL4.jpg',
#          'Turismo': '/resizer/FibfXejdhUuvyJfvtCsTn7oU0Ro=/arc-anglerfish-arc2-prod-elespectador/public/KPKQWMU5ZRA7LJC6NAO33KJ224.png'},
#         'ad': True,
#         'excludeURLS': ['/colombia-20', '/impacto-mujer'],
#         'logosURLS': {'/gastronomia-y-recetas': '',
#          '/colombia-20': '',
#          '/el-magazin-cultural/': '',
#          '/turismo': '',
#          '/autos': '',
#          '/impacto-mujer': '',
#          '/desaparecidos-colombia': '',
#          '/la-red-zoocial': ''},
#         'removeH1': True,
#         'bmcImage': '',
#         'bmcTitle': '',
#         'bmcHook': '',
#         'bmcLink': ''},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}}]},
#    {'collection': 'sections',
#     'props': {'collection': 'sections', 'id': 1},
#     'children': [{'collection': 'features',
#       'type': 'global/OnLive',
#       'props': {'collection': 'features',
#        'type': 'global/OnLive',
#        'id': 'f0fsWErVDtwx32J',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {'dataTitle': 'La situación de los defensores ambientales en Colombia',
#         'dataURL': '<iframe src="https://www.facebook.com/plugins/video.php?height=314&href=https%3A%2F%2Fwww.facebook.com%2Felespectadorcom%2Fvideos%2F1321262654994930%2F&show_text=false&width=560&t=0" width="560" height="314" style="border:none;overflow:hidden" scrolling="no" frameborder="0" allowfullscreen="true" allow="autoplay; clipboard-write; encrypted-media; picture-in-picture; web-share" allowFullScreen="true"></iframe>',
#         'dataDescription': 'Colombia sigue liderando la lista de países más violentos contra las personas que luchan por cuidar el medio ambiente. ¿Qué podemos hacer?',
#         'dataDateTime': '2021-10-07 11:00:00',
#         'dataDuration': 2,
#         'dataPublish': False},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}}]},
#    {'collection': 'sections',
#     'props': {'collection': 'sections', 'id': 2},
#     'children': [{'collection': 'features',
#       'type': 'global/Breadcrumbs',
#       'props': {'collection': 'features',
#        'type': 'global/Breadcrumbs',
#        'id': 'f0fB27FMzg8p3S2',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}},
#      {'collection': 'features',
#       'type': 'Article/body',
#       'props': {'collection': 'features',
#        'type': 'Article/body',
#        'id': 'f0fDk9VIQIGM1Ix',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}}]},
#    {'collection': 'sections',
#     'props': {'collection': 'sections', 'id': 3},
#     'children': []},
#    {'collection': 'sections',
#     'props': {'collection': 'sections', 'id': 4},
#     'children': []},
#    {'collection': 'sections',
#     'props': {'collection': 'sections', 'id': 5},
#     'children': [{'collection': 'features',
#       'type': 'global/widget',
#       'props': {'collection': 'features',
#        'type': 'global/widget',
#        'id': 'f0fbtWd8n2Bz7P4',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {'idWidget': '520c0f08c83375428cafc56caffa1bdb770a7afc',
#         'idDiv': 'isTrending',
#         'regexRule': {'/cromos': 'e6e9c7d422cf70641fa41eec251bb6870651a116',
#          '/revista-vea': 'ec7a7fe303b83d87710910c2f0e294dcc8209c97'}},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}},
#      {'collection': 'features',
#       'type': 'global/Partners',
#       'props': {'collection': 'features',
#        'type': 'global/Partners',
#        'id': 'f0fJMyQPAHwK7Ng',
#        'name': 'multialiados',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {'data': {'Idiomas content': '[{"name":"Mejora tu italiano con 15 minutos al día","url":"https://idiomas.elespectador.com/es/saga-baldoria","description":"El Espectador te entrega 21 días gratis de curso de italiano. Disfruta de nuestras lecciones personalizadas, breves y divertidas.", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/6Z2TPHZMF5HBNP353XXB2YAM5U.png"}]},{"name":"Mejora tu inglés con 15 minutos al día","url":"https://idiomas.elespectador.com/es/gymglish","description":"El Espectador te entrega 21 días gratis de curso de inglés. Disfruta de nuestras lecciones personalizadas, breves y divertidas.", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/M6BUHXXGIZHFRLQMMSSJ6XRTQQ.png"}]},{"name":"Mejora tu francés con 15 minutos al día","url":"https://idiomas.elespectador.com/es/frantastique","description":"El Espectador te entrega 21 días gratis de curso de francés. Disfruta de nuestras lecciones personalizadas, breves y divertidas. ", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/3OANR2ZDSNCCLJWSLOKXNZMYDE.png"}]},{"name":"Mejora tu alemán con 15 minutos al día","url":"https://idiomas.elespectador.com/es/wunderbla","description":"El Espectador te entrega 21 días gratis de curso de alemán. Disfruta de nuestras lecciones personalizadas, breves y divertidas. ", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X7XLKJKRNNEYTPYKWXA4BK66AY.png"}]},{"name":"Improve your Spanish with 15 minutes per day","url":"https://idiomas.elespectador.com/en/hotel-borbollon","description":"El Espectador offers you 21 free days of Spanish lessons. Enjoy our personalized, short and fun lessons.", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/XQVVFFAOMFH7ROPHBKFFMRH3CI.png"}]}]',
#          'Idiomas bannerLink': 'https://idiomas.elespectador.com/es/gymglish',
#          'Suscripciones content': '[{"name":"Te tenemos un plan","url":"https://www.elespectador.com/somos-espectador/#planes","description":"Conoce nuestras opciones de suscripciones para que siempre cuentes con un plan de información.", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/RC4XWUOIVNEGVMQVT34PTGWSFE.png"}]},{"name":"Te ofrecemos distintas opciones","url":"https://www.elespectador.com/otras-formas-de-pago/?_ptid=%7Bkpdx%7DAAABIPaliGr-","description":"Conoce nuestros distintos medios de pago para que adquieras con toda confianza tu plan de información.", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/2WRJP6SGYBCKPN2RD63A6JMVBQ.png"}]},{"name":" La mejor colección de libros","url":" https://www.buscalibre.com.co/?utm_nooverride=1&gclid=CjwKCAiAy_CcBhBeEiwAcoMRHJgoVsyci2OXa05IafKrQZeCemJO0GeZaaVToUlHm2UlusfU67e8XRoC01gQAvD_BwE","description":" Adquiere tus títulos favoritos con un beneficio único", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/T2KWY6LO6BDV7DIBA7EO6DH7FU.jpeg"}]},{"name":"Aprovecha esta gran oportunidad","url":"https://www.elespectador.com/promo-maestros/","description":"Adquiere tu plan de información a precio especial.", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/ETYG3IGMEZBEDCGQNNUUC6QT5M.png"}]},{"name":"Suscripción digital básica del The New York Times","url":"https://www.elespectador.com/suscripcion-digital/anual-basico/?utm_source=interno&utm_medium=bloque_home&utm_campaign=multialiados","description":"Acceso a los archivos completos desde 1851.", "imagen":[{"breakpoint": "360","uri":"https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/AUD34347SRAWHFBAXY6UWEVL4U.jpeg"}]}]'},
#         'utm': '?utm_source=interno&utm_medium=bloque_articulos&utm_campaign=multialiados'},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}},
#      {'collection': 'features',
#       'type': 'global/Newsletter',
#       'props': {'collection': 'features',
#        'type': 'global/Newsletter',
#        'id': 'f0fyRHlO0oM97K5',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {'checkboxGroup': True,
#         'checkboxGroupTitle': 'Inscríbete a nuestros Newsletters',
#         'checkboxGroupDescription': 'Conoce nuestra oferta de newsletters e infórmate de manera ágil y personalizada desde tu correo electrónico',
#         'checkboxGroupExample': 'Ejemplo: andrea.perez@elespectador.com',
#         'hideOnDesktop': True,
#         'opinionCardOnly': True},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}}]},
#    {'collection': 'sections',
#     'props': {'collection': 'sections', 'id': 6},
#     'children': [{'collection': 'features',
#       'type': 'global/Footer',
#       'props': {'collection': 'features',
#        'type': 'global/Footer',
#        'id': 'f0fDkjmy6Rvo7k3',
#        'contentConfig': {'contentService': '',
#         'contentConfigValues': {},
#         'inherit': True},
#        'customFields': {'links': {'video': '/video/',
#          'podcast': '/podcast-espanol-el-espectador/',
#          'historias': '/historias-visuales/',
#          'eventos': '/eventos-ee/',
#          'pasatiempos': 'https://pasatiempos.elespectador.com/',
#          'ayuda': '/ayuda-el-espectador/',
#          'suscripcion': '/suscripcion-digital/?utm_source=interno&utm_medium=boton&utm_campaign=suscripcion_digital&utm_content=boton_footer',
#          'terminos': '/terminos/terminos-y-condiciones/',
#          'politicas': '/terminos/politica-de-tratamiento-de-datos/',
#          'iab': 'https://www.iabcolombia.com/',
#          'sic': 'https://www.sic.gov.co/',
#          'ami': 'https://ami.org.co/',
#          'android': 'https://play.google.com/store/search?q=el%20espectador&c=apps&hl=es_CO&gl=US',
#          'ios': 'https://apps.apple.com/co/app/el-espectador-app/id461138822',
#          'newsletter': '/newsletters/',
#          'premium': '/para-ti/premium/',
#          'impreso': '/edicion-impresa/'},
#         'rows': 8,
#         'columns': 4},
#        'displayProperties': {},
#        'localEdits': {},
#        'variants': {}}}]}]}]

# %% [markdown]
# The pattern behind the list in which our data is contained. It's changing so: listCoverpageNewsString[1]['content_elements'][changing part]['content']
#
# Ahead we'll see a trick to run through every element avoiding excepetions successfully

# %%
listCoverpageNewsString[1]['content_elements'][0]['content']
# Out:
# 'Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.'

# %%
listCoverpageNewsString[1]['content_elements'][2]['content']
# Out:
# 'Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.'

# %%
#The length of list containing the objective data

len(listCoverpageNewsString[1]['content_elements'])
# Out:
# 45

# %% [markdown]
# We detect our Key Error identifying the pattern the list have at the time of looking for our data on an ordered way. Everything is kept in a python list through the append methodm taking into account the variation of data into the json format

# %%
#We detect our Key Error identifying the pattern the list have at the time of looking for our data on an ordered way. Everything is kept in a python list through
#the append methodm taking into account the variation of data into the json format
articleComplete = []
contentArt = listCoverpageNewsString[1]['content_elements']
count = 0
for microContent in contentArt[0:len(contentArt)]:
  try:
    part = listCoverpageNewsString[1]['content_elements'][count]['content']
    articleComplete.append(part)
  except KeyError:
    pass
  count = 1 + count


len(articleComplete)
# Out:
# 44

# %%
#The list with the objective data
articleComplete
# Out:
# ['Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.',
#  'Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.',
#  'Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024.',
#  '<b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/finanzas-personales/es-buen-momento-para-endeudarse-asi-estan-los-creditos-en-2024-noticias-colombia/" target="_blank"><i><b>¿Es buen momento para endeudarse?: así está el panorama del crédito en 2024</b></i></a>',
#  'Al mirar en el retrovisor, lejos ha quedado ya aquel temido noviembre de 2022, cuando el dólar subió más allá del umbral de los $5.000, desatando un frenesí de compra en el que muchas personas se agolparon en las taquillas de las casas de cambio por el temor a que el billete verde se siguiera encumbrando hasta aplastar al peso colombiano y, de paso, la capacidad adquisitiva de miles de consumidores. Hoy, muchos se sonrojan al recordar este episodio.',
#  'Pero allá, donde el horizonte se pierde, está un 2014 donde el dólar valía $2.000. Días que no volverán, especialmente tras una pandemia, una espiral inflacionaria generalizada y una desaceleración económica global.',
#  'Sin ir más lejos, de un año hacia acá la tasa de cambio del dólar ha caído más o menos unos $1.000 y en lo corrido de 2024 la divisa ha transcurrido entre mínimos de <b>$3.889 y máximos de $3.975 </b>en su Tasa Representativa del Mercado (TRM).',
#  '<iframe title="Tasa Representativa del Mercado en 2023" aria-label="Interactive line chart" id="datawrapper-chart-b0ujw" src="https://datawrapper.dwcdn.net/b0ujw/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();\r\n</script>\r\n',
#  'Varios analistas coinciden en que el arranque del año ha estado marcado por una inusitada estabilidad en la moneda estadounidense, después de un par de años donde nos acostumbró a la volatilidad.',
#  '“Los movimientos en lo corrido de 2024 lo que están haciendo es consolidar la tasa de cambio en unos niveles más estables y sostenibles y se espera que esto siga así”, explica <b>Sergio Olarte</b>, economista principal de Scotiabank Colpatria.',
#  '<b>Lea también: </b><a href="https://www.elespectador.com/economia/super-bowl-publicidad-y-economia-como-el-evento-es-una-maquina-de-hacer-dinero/" target="_blank"><b>Super Bowl, publicidad y economía: cómo el evento es una máquina de hacer dinero</b></a>',
#  'No obstante, Olarte advierte que la volatilidad de la moneda se incrementó en las últimas semanas, con cambios de $20 de un día para otro a cambios de $50 y hasta $100. Esto, entre otras cosas, por recientes comentarios de firmas calificadoras de riesgo (como S&amp;P Global Ratings) acerca de la economía colombiana.',
#  '<iframe title="TRM en 2024" aria-label="Interactive line chart" id="datawrapper-chart-mm185" src="https://datawrapper.dwcdn.net/mm185/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();\r\n</script>\r\n',
#  'Dentro de las proyecciones para la tasa de cambio, los analistas estiman un dólar más barato al cierre del primer trimestre del año. Un factor a tener en cuenta si está planeando comprar divisas ahora. Sin embargo, las propias proyecciones del Gobierno en su Plan Financiero establecen que la tasa de cambio se ubicará por encima de los $4.000 para terminar 2024.',
#  '<b>Lea también: </b><a href="https://www.elespectador.com/economia/las-alarmas-en-el-plan-financiero-2024-del-gobierno-segun-anif-noticias-colombia/" target="_blank"><b>Las alarmas que enciende el Plan Financiero 2024 del Gobierno</b></a>',
#  '¿Es buen momento para invertir en dólares?',
#  '“El dólar puede bajar un poco más al cierre del primer trimestre e, incluso, más en el segundo trimestre del año, atendiendo a que la inflación está controlada en Estados Unidos, se acerca a la meta del 2 %, y la Reserva Federal disminuirá su tasa de interés este año. Esto hará que el mercado estadounidense sea menos atractivo para invertir y los inversionistas buscarán economías emergentes, como la nuestra, donde los intereses han venido bajando, pero siguen siendo altos para la región”, explica <b>Sebastián Chacón</b>, director de la Escuela de Negocios y Desarrollo Internacional del Politécnico Grancolombiano.',
#  'En la misma línea, <b>Felipe Campos</b>, gerente de Estrategia e Inversión de Alianza Fiduciaria, explica que monedas como las de Colombia o México han resistido bien los incrementos en el dólar a comparación del resto de la región, de ahí que permanezcan con relativa poca volatilidad.',
#  'Para el experto en inversiones, el dólar tendría presiones bajistas en el corto plazo, por ejemplo, el dato de inflación en Estados Unidos para enero de 2024 (que se conocerá en los próximos días).',
#  '<b>Lea también: </b><a href="https://www.elespectador.com/economia/armando-benedetti-a-la-fao-le-sirve-a-colombia-tener-nuevo-embajador-en-la-organizacion/" target="_blank"><b>Benedetti a la FAO: ¿le sirve a Colombia tener nuevo embajador en la organización?</b></a>',
#  '“Y si el dólar baja más, nos gustaría comprarlo en ese momento porque el resto del año va a ser movido. Se vienen los trámites de las reformas en Colombia, antes de junio, y luego las elecciones en Estados Unidos”, indica Campos.',
#  'El primer consejo al invertir es que se debe hacerlo cuando esa acción, esa criptomoneda, ese gramo de oro o el activo que le llame la atención (el dólar en este caso) esté bajando de precio.',
#  'Así las cosas, puede que sea muy pronto para apostarle a una divisa que, como indican los pronósticos, podría ser más barata al cabo de algunas semanas. Si tiene un viaje al exterior o una compra internacional en mente, quizá le convenga esperar unas semanas para comprar dólares.',
#  'Dicho esto, siempre es clave mencionar que el mundo gira y gira y estas proyecciones bien pueden verse alteradas de un día para otro debido a eventos globales que le pegan a una serie de factores económicos (hablamos de eventos como guerras, pandemias, inestabilidad política...). No hay una respuesta única, certera y a prueba de coyunturas acerca del precio del dólar, en últimas.',
#  '<b>¿El dólar ya no es buen negocio?</b>',
#  'Por décadas, la compra de dólares era el vehículo al cual se subían quienes querían ganarse unos pesos aprovechando la tasa de cambio, resguardarse de la inflación confiando en una moneda más fuerte que la nuestra o construir un patrimonio sin aventurarse en las turbulencias de la bolsa de valores.',
#  'Esto ha venido cambiando y la compra de dólares en sí misma (es decir, cambiar pesos por su equivalente en divisa americana) ha perdido algo de su atractivo para 2024.',
#  '“En 2022, la compra de dólares enriqueció a muchos. La divisa estuvo en niveles bajos durante una parte del año, hasta que la incertidumbre económica -un factor clave aquí- fue llevándola a precios tan altos como los $5.200. Ahora, el escenario es bastante distinto: nuestra inflación viene bajando, la Fed ha dicho que bajará tasas en algún momento del año y, en general, hay un mercado de certidumbre donde no se esperan movimientos bruscos de la tasa de cambio”, asevera <b>Henry Amorocho</b>, profesor de Hacienda Pública y Presupuesto de la Universidad del Rosario.',
#  '<b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/macroeconomia/la-inflacion-arranca-2024-bajando-en-enero-y-acumula-10-meses-de-descensos-continuos/" target="_blank"><i><b>La inflación arranca 2024 bajando y acumula 10 meses de descensos continuos</b></i></a>',
#  'Dicen los analistas que los dólares (y cualquier divisa) son buen negocio cuando hay grandes “espacios cambiarios”, es decir, amplias distancias entre el precio actual del dólar y el que tendría en el futuro. Lo cierto es que esta franja, a día de hoy, es pequeña, así como las ganancias que tendría un inversionista.',
#  'Por ejemplo, la mayoría de los analistas económicos consultados por el Banco de la República en enero pasado previó una Tasa Representativa del Mercado (TRM) entre los <b>$3.839 y $3.939</b> durante 2024. Así mismo, los más recientes pronósticos de Fedesarrollo indican que la TRM no será mayor a <b>$4.025</b> a diciembre de 2024.',
#  'Con un dólar a <b>$3.922</b> al cierre del pasado 9 de febrero, la eventual valorización de una inversión en dólares en 2024 -bajo un escenario sin sorpresas- podría no ser suficientemente jugosa para algunos inversionistas.',
#  '“Creemos que el dólar está cambiando de tendencia después de 12 años. Ya no consideramos que vaya a tener un gran valor en el largo plazo, pero sigue siendo un activo importante para diversificar, porque si a Colombia le va mal, al dólar le va bien. Entonces siempre se debe tener algo en dólar”, aconseja el gerente de Estrategia e Inversión de Alianza Fiduciaria.',
#  'En esto coincide <b>Michael Ortegón</b>, decano de la Facultad de Ciencias Económicas y Administrativas de UNINPAHU, quien explica que la compra de dólares solo debe hacerse para hacer inversiones que agregarán más valor en el largo plazo.',
#  '“El dólar no se debe usar como medio de cambio o para “ahorrarlo” en cuentas de ahorro que no ganan ningún interés por estar depositados. En cualquier caso, la moneda estadounidense estará por encima del peso colombiano, pero eso no implica que sea buena idea comprar dólares”, agrega el académico.',
#  'Se suele recomendar que entre un 20 % a un 30 % de los ahorros de una persona estén tasados en una moneda extranjera (como el dólar), ya sea en algún fondo de inversión o en cuentas tasadas en divisas, las cuales son ofrecidas por la mayoría de los bancos en Colombia. Eso sí, estos productos están destinados a depósitos por encima de los $30 millones.',
#  '<b>Activos en dólares</b>',
#  'Si apostarles a los billetes verdes (por sí solos) no es tan recomendable en este momento, el panorama es muy distinto para los activos tasados en dólares, tales como las acciones, los bonos del Tesoro o los inmuebles.',
#  '“El activo en dólares que mejor le está yendo son las acciones de empresas estadounidenses, que están disparadas y están teniendo mucho mejor retorno que el resto de acciones en el mundo, gracias a los resultados de las empresas de tecnología”, afirma Felipe Campos.',
#  'En esto coincide el decano de UNINPAHU, quien resalta que “ciertos activos valuados en dólares muestran un desempeño positivo, destacándose las acciones tecnológicas de empresas líderes como Apple, Microsoft y Amazon. Además, el mercado inmobiliario se mantiene sólido (debido a las tasas de interés altas), con propiedades residenciales y comerciales conservando su valor; mientras que el oro, considerado a menudo como un refugio seguro, ha experimentado un aumento en su precio”.',
#  '<b>Puede interesarle:</b><a href="https://www.elespectador.com/economia/la-reserva-federal-bajara-las-tasas-de-interes-en-estados-unidos/" target="_blank"><b> </b><i><b>¿Tasas de interés más bajas en EE.UU.?: sí, pero no tan rápido</b></i></a>',
#  'Finalmente, Olarte, el economista principal de Scotiabank Colpatria destaca que “se podría pensar en acciones en Estados Unidos que podrían seguir valorizándose o alguna inversión inmobiliaria que salga más o menos rentable (…). Los activos que están teniendo un buen momento son alguna parte de las acciones en Estados Unidos, porque se espera que las tasas de interés bajen y eso puede ayudar a que la parte bursátil del mundo se mejore”.',
#  'Tenga en cuenta que si va a invertir en activos de alto riesgo, como la renta variable (acciones), lo mejor es asesorarse con profesionales. En materia de dólar, el mejor consejo en este momento es actuar con prudencia. Lo que indican los analistas es que parece no ser el mejor momento para vender casa, carro o invertir sus ahorros en una moneda que, parece, podría no dar los mejores resultados.',
#  '💰📈💱 <b>¿Ya te enteraste de las últimas noticias </b><a href="https://www.elespectador.com/economia"><b>económicas</b></a><b>? </b>Te invitamos a verlas en <a href="https://www.elespectador.com/economia/">El Espectador</a>.']

# %%
#Becoming everything into a string
articleString = ''
count = 0
for art in articleComplete[0:len(articleComplete)]:
  part = articleComplete[count]
  articleString = articleString + '\n\n'+ part
  count += 1
articleString
# Out:
# '\n\nInvertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.\n\nComprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.\n\nSiguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024.\n\n<b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/finanzas-personales/es-buen-momento-para-endeudarse-asi-estan-los-creditos-en-2024-noticias-colombia/" target="_blank"><i><b>¿Es buen momento para endeudarse?: así está el panorama del crédito en 2024</b></i></a>\n\nAl mirar en el retrovisor, lejos ha quedado ya aquel temido noviembre de 2022, cuando el dólar subió más allá del umbral de los $5.000, desatando un frenesí de compra en el que muchas personas se agolparon en las taquillas de las casas de cambio por el temor a que el billete verde se siguiera encumbrando hasta aplastar al peso colombiano y, de paso, la capacidad adquisitiva de miles de consumidores. Hoy, muchos se sonrojan al recordar este episodio.\n\nPero allá, donde el horizonte se pierde, está un 2014 donde el dólar valía $2.000. Días que no volverán, especialmente tras una pandemia, una espiral inflacionaria generalizada y una desaceleración económica global.\n\nSin ir más lejos, de un año hacia acá la tasa de cambio del dólar ha caído más o menos unos $1.000 y en lo corrido de 2024 la divisa ha transcurrido entre mínimos de <b>$3.889 y máximos de $3.975 </b>en su Tasa Representativa del Mercado (TRM).\n\n<iframe title="Tasa Representativa del Mercado en 2023" aria-label="Interactive line chart" id="datawrapper-chart-b0ujw" src="https://datawrapper.dwcdn.net/b0ujw/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();\r\n</script>\r\n\n\nVarios analistas coinciden en que el arranque del año ha estado marcado por una inusitada estabilidad en la moneda estadounidense, después de un par de años donde nos acostumbró a la volatilidad.\n\n“Los movimientos en lo corrido de 2024 lo que están haciendo es consolidar la tasa de cambio en unos niveles más estables y sostenibles y se espera que esto siga así”, explica <b>Sergio Olarte</b>, economista principal de Scotiabank Colpatria.\n\n<b>Lea también: </b><a href="https://www.elespectador.com/economia/super-bowl-publicidad-y-economia-como-el-evento-es-una-maquina-de-hacer-dinero/" target="_blank"><b>Super Bowl, publicidad y economía: cómo el evento es una máquina de hacer dinero</b></a>\n\nNo obstante, Olarte advierte que la volatilidad de la moneda se incrementó en las últimas semanas, con cambios de $20 de un día para otro a cambios de $50 y hasta $100. Esto, entre otras cosas, por recientes comentarios de firmas calificadoras de riesgo (como S&amp;P Global Ratings) acerca de la economía colombiana.\n\n<iframe title="TRM en 2024" aria-label="Interactive line chart" id="datawrapper-chart-mm185" src="https://datawrapper.dwcdn.net/mm185/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var ...

# %%
# Getting additional information of our main soup (soup1)
coverpage_newsTitle = soup1.find('title')
title = coverpage_newsTitle.get_text()
title
# Out:
# 'Comprar dólares: ¿cómo están las aguas para invertir en la divisa? | Noticias Colombia | EL ESPECTADOR'

# %%
soup1
# Out:
# <!DOCTYPE html>
# <html lang="es"><head><meta charset="utf-8"/><link href="/pf/dist/css/el-espectador.css?d=823" rel="stylesheet"/><link href="/pf/resources/styles/newsletterStructure.css?d=823" rel="stylesheet"/><title>Comprar dólares: ¿cómo están las aguas para invertir en la divisa? | Noticias Colombia | EL ESPECTADOR</title><meta content="Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos." name="description"/><meta content="Noticias económicas, comprar dolares, invertir en dolares, dolar a peso colombiano, dolar febrero 2024, inversion, consejos para invertir, consejos para invertir en dolares, dolar en Colombia, donde comprar dolares, inversion en Colombia, en que invertir 2024" name="keywords"/><meta content="Noticias económicas, comprar dolares, invertir en dolares, dolar a peso colombiano, dolar febrero 2024, inversion, consejos para invertir, consejos para invertir en dolares, dolar en Colombia, donde comprar dolares, inversion en Colombia, en que invertir 2024" name="news_keywords"/><meta content="follow, index, max-snippet:150, max-image-preview:large  " name="robots"/><link href="https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/?outputType=amp" rel="amphtml"/><link href="https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/" rel="canonical"/><link href="https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/" hreflang="es" rel="alternate"/><meta content="spanish" name="language"/><meta content="news" name="genre"/><meta content="width" name="MobileOptimized"/><meta content="true" name="HandheldFriendly"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="El Espectador" name="author"/><meta content="Inicio" property="ps:breadCrumb"/><meta content="Home" property="ps:contentTemplate"/><meta content="home" property="ps:pageName"/><meta content="ELESPECTADOR.COM" property="og:site_name"/><meta content="https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/" property="og:url"/><meta content="Comprar dólares: ¿cómo están las aguas para invertir en la divisa?" property="og:title"/><meta content="Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos." property="og:description"/><meta content="https://www.elespectador.com/resizer/_USflWlKEX9yGRyMCX72DFxCfro=/657x0/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg" property="og:image"/><meta content="Colombia" property="og:country_name"/><meta content="article" property="og:type"/><meta content="summary_large_image" name="twitter:card"/><meta content="@elespectador" name="twitter:site"/><meta content="@elespectador" name="twitter:creator"/><meta content="https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/" name="twitter:url"/><meta content="Comprar dólares: ¿cómo están las aguas para invertir en la divisa?" property="twitter:title"/><meta content="Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos." property="twitter:description"/><meta content="https://www.elespectador.com/resizer/_USflWlKEX9yGRyMCX72DFxCfro=/657x0/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg" name="twitter:image"/><meta content="Comprar dólares: ¿cómo están las aguas para invertir en la divisa? | Noticias Colombia" name="twitter:image:alt"/><meta content="687966271952902" property="fb:app_id"/><meta content="14302129065" property="fb:pages"/><me ...
#   window._vwo_code=window._vwo_code|| (function() {
#
#
#       settings_tolerance=5000,
#       library_tolerance=5000,
#       use_existing_jquery=false,
#
#       hide_element='body',
#
#       /* DO NOT EDIT BELOW THIS LINE */
#       f = false, d = document, code = { use_existing_jquery: function () { return use_existing_jquery; }, library_tolerance: function () { return library_tolerance; }, finish: function () { if (!f) { f = true; var a = d.getElementById('_vis_opt_path_hides'); if (a) a.parentNode.removeChild(a); } }, finished: function () { return f; }, load: function (a) { var b = d.createElement('script'); b.src = a; b.type = 'text/javascript'; b.innerText; b.onerror = function () { _vwo_code.finish(); }; d.getElementsByTagName('head')[0].appendChild(b); }, init: function () { window.settings_timer = setTimeout(function () { _vwo_code.finish() }, settings_tolerance); var a = d.createElement('style'), b = hide_element ? hide_element + '{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}' : '', h = d.getElementsByTagName('head')[0]; a.setAttribute('id', '_vis_opt_path_hides'); a.setAttribute('type', 'text/css'); if (a.styleSheet) a.styleSheet.cssText = b; else a.appendChild(d.createTextNode(b)); h.appendChild(a); return settings_timer; }}; window._vwo_settings_timer = code.init(); return code;}());
#     </script><script async="" referrerpolicy="no-referrer-when-downgrade" src="https://dev.visualwebsiteoptimizer.com/j.php?a=612785&amp;f=1"></script><script async="" defer="" src="/pf/resources/scripts/minified/taboolaArticle.minified.js?d=823"></script><script id="polyfill-script" type="application/javascript">if(!Array.prototype.includes||!(window.Object && window.Object.assign)||!window.Promise||!window.Symbol||!window.fetch){document.write('<script type="application/javascript" src="/pf/dist/engine/polyfill.js?d=823" defer=""><\/script>')}</script><script defer="" id="fusion-engine-react-script" src="/pf/dist/engine/react.js?d=823" type="application/javascript"></script><script defer="" id="fusion-engine-combinations-script" src="/pf/dist/components/combinations/default.js?d=823" type="application/javascript"></script><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon.svg?d=823" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon.svg?d=823" rel="icon" type="image/svg+xml"/><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon-16.svg?d=823" rel="icon" sizes="16x16" type="image/svg+xml"/><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon-32.svg?d=823" rel="icon" sizes="32x32" type="image/svg+xml"/><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon-48.svg?d=823" rel="icon" sizes="48x48" type="image/svg+xml"/><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon-76.svg?d=823" rel="icon" sizes="76x76" type="image/svg+xml"/><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon-96.svg?d=823" rel="icon" sizes="96x96" type="image/svg+xml"/><link href="https://www.elespectador.com/pf/resources/images/favicons/favicon-EE-120.png?d=823" rel="apple-touch-icon-precomposed" sizes="120x120" type="image/png"/><link href="https://www.elespectador.com/pf/resources/images/favicons/favicon-EE-152.png?d=823" rel="apple-touch-icon-precomposed" sizes="152x152" type="image/png"/><link href="https://www.elespectador.com/pf/resources/images/favicons/favicon-EE-167.png?d=823" rel="apple-touch-icon-precomposed" sizes="167x167" type="image/png"/><link href="https://www.elespectador.com/pf/resources/images/favicons/favicon-EE-180.png?d=823" rel="apple-touch-icon-precomposed" sizes="180x180" type="image/png"/><link href="https://www.elespectador.com/pf/resources/images/favicons/logoFavicon-192.svg?d=823" rel="icon" sizes="192x192" type="image/svg+xml"/><link href="/manifest.json" rel="manifest"/><script crossorigin="anonymous" defer="" integrity="sha256-kZdkZhqgFNaGr6uXhjDI1wJie4rPdXuwZIwGvbkmxAI= sha384-16NHxQ56nk9L6mYJEMueErCQy3apXT3t+s3Zln/9Cb5r65PyVoyYWc1Xis2AyLeO sha512-juG4T5LbIw5oIaxRM4SsstO0WEuz3c6BwPhhzgIXvy98OM7UiZsvzCcTz7Is0zGHHIBPaDkCvJ3++uUqBFkRUg==" src="https://cdnjs.cloudflare.com/ajax/libs/crypto-js/4.0.0/core.js"></script><script crossorigin="anonymous" defer="" integrity="sha256-HX0j5mAQX1PZWyNi/7GYv7G27BRBRlmNKXHbGv4fUYg= sha384-8grjJYqm7LKLYU+wyJNSF5VuUdBkO2nhlP5uc1Yucc9Q1UfngglfeZonVNCLIoCR sha512-VLDQac8zlryHkFvL1HIH9KKjkPNdsNLEXM/vImKGMaNkEXbNtb+dyhnyXFkxai1RVNtwrD5L7vffgtzYzeKI3A==" src="https://cdnjs.cloudflare.com/ajax/libs/crypto-js/4.0.0/md5.min.js"></script><script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@type":"Organization",
#     "name":"El Espectador",
#     "url":"https://www.elespectador.com",
#     "logo":{
#       "@type":"ImageObject",
#       "url":"/pf/resources/images/favicons/favicon-EE-152.png?d=823",
#       "width":"300"
#     },
#     "contactPoint": {
#       "@type": "ContactPoint",
#       "telephone": "018000510903",
#       "contactType": "Servicio al cliente"
#     },
#     "sameAs":[
#       "https://www.facebook.com/elespectadorcom",
#       "https://twitter.com/elespectador",
#       "https://www.instagram.com/elespectador/",
#       "https://www.youtube.com/user/Elespectadorcom?sub_confirmation=1"
#     ]}
#     </script><script type="application/ld+json">{
#   "@context": "http://schema.org",
#   "@type": "WebSite",
#   "name": "El Espectador",
#   "url": "https://www.elespectador.com",
#   "sameAs":[
#     "https://www.facebook.com/elespectadorcom",
#     "https://twitter.com/elespectador",
#     "https://www.instagram.com/elespectador/",
#     "https://www.youtube.com/user/Elespectadorcom?sub_confirmation=1"
#   ]
#   ,
#       "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https://www.elespectador.com/buscador/{q}",
#         "query-input": "required name=q"
#       }
# }</script><script src="https://tags.denakop.com/pd/denakop.js" type="text/javascript"></script>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
#                               <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="GRJMD-A2LGW-55R3Y-KNEZE-U6B3Q",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"GRJMD-A2LGW-55R3Y-KNEZE-U6B3Q";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="ejlikqyxbsitezokcnna-f-b157e880c-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"36","ak.cp":"927404","ak.ai":parseInt("594085",10),"ak.ol":"0","ak.cr":63,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"1c3d93","ak.r":36534,"ak.a2":n,"ak.m":"dscr","ak.n":"ff","ak.bpcip":"34.86.133.0","ak.cport":55594,"ak.gh":"23.32.17.50","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1707742042","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"48","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head><body class=""><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5FQVPR" style="display:none;visibility:hidden" widt ...
#   "@context": "http://schema.org",
#   "@graph": [
#   {"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Últimas Noticias", "url": "/ultimas-noticias-colombia/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Opinión", "url": "/opinion/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Política", "url": "/politica/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Judicial", "url": "/judicial/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Economía", "url": "/economia/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Mundo", "url": "/mundo/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Bogotá", "url": "/bogota/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Empleos", "url": "/empleos/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Deportes", "url": "/deportes/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_horizontal"},{"@context": "http://schema.org","@type": "SiteNavigationElement","name":"Colombia + 20", "url": "/colombia-20/?utm_source=interno&utm_medium=boton&utm_campaign=menu_horizontal&utm_content=boton_menu_col-20"}
#   ]}</script><div class="Nav Nav-principal Nav-principalundefined Nav_onlyDesktop"><nav class="Nav-ulSection"><div class="Nav-ul"><div class="Nav-il false"><a class="Nav-a false" href="/ultimas-noticias-colombia/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Últimas Noticias">Últimas Noticias</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/opinion/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Opinión">Opinión</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/politica/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Política">Política</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/judicial/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Judicial">Judicial</h3></a></div><div class="Nav-il false Nav-il_active"><a class="Nav-a false" href="/economia/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder Nav-TitleSection_active" data-section="Economía">Economía</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/mundo/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Mundo">Mundo</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/bogota/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Bogotá">Bogotá</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/empleos/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Empleos">Empleos</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/deportes/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_horizontal"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Deportes">Deportes</h3></a></div><div class="Nav-il false"><a class="Nav-a false" href="/colombia-20/?utm_source=interno&amp;utm_medium=boton&amp;utm_campaign=menu_horizontal&amp;utm_content=boton_menu_col-20"><h3 class="Nav-TitleSection Nav-TitleSectionWithoutBorder" data-section="Colombia + 20">Colombia + 20</h3></a></div></div></nav></div></div><div class="Header-TopBarAside" data-google-interstitial="false"><div class="Header-AsideContainer"></div><div class="Header-Control"></div><div class="Header-UserArea"><div class="Header-User Header-IconSpan" id="UserAvatarContainer"><div class="`Header-UserContainer" style="display:flex"><div class="Header-Anon"><svg style="display:inline-block;stroke:currentColor;fill:currentColor" viewBox="0 0 1024 1024"><path d="M512 0c-116.19 0-225.569 37.879-315.372 109.38-5.533 4.256-9.363 11.066-10.214 17.875-0.851 7.235 1.277 14.045 5.533 19.578s10.64 8.938 17.45 9.789c6.81 0.426 14.045-1.277 19.578-5.958 81.29-63.84 179.179-97.889 283.026-97.889 253.234 0 459.225 205.992 459.225 459.225 0 96.612-29.367 188.968-85.546 266.427-87.674-117.466-226.846-187.265-373.679-187.265s-285.579 69.799-373.679 187.265c-56.18-77.46-85.546-169.815-85.546-266.427 0-102.996 33.197-200.033 95.761-280.047 8.938-11.491 6.81-28.515-4.682-37.453-11.491-8.512-28.09 ...
#     "@context": "https://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#       {
#         "@type": "ListItem",
#         "position": 0,
#         "item":
#         {
#           "@id": "/",
#           "name": "Home"
#         }
#       },
#
#           {
#             "@type": "ListItem",
#             "position": 1,
#             "item":
#             {
#               "@id": "/economia",
#               "name": "Economía"
#             }
#           },
#           {
#             "@type": "ListItem",
#             "position": 2,
#             "item":
#             {
#               "@id": "/economia/finanzas-personales",
#               "name": "Finanzas personales"
#             }
#           }
#     ]
#   }</script><span><div class="Breadcrumb Breadcrumb_article"><div class="Breadcrumb-Container"><span class="Breadcrumb-Text"><a href="/"><h3>Home</h3></a></span><span class="Breadcrumb-Text"><svg class="Breadcrumb Breadcrumb-Icon" style="display:inline-block;stroke:currentColor;fill:currentColor" viewBox="0 0 1024 1024"><path d="M323.738 1038.541c0.004 0 0.009 0 0.014 0 11.648 0 22.195-4.715 29.836-12.34l-0.001 0.001 348.16-348.16c40.62-40.697 65.738-96.877 65.738-158.925s-25.119-118.228-65.742-158.928l0.003 0.003-348.16-348.16c-7.696-8.051-18.521-13.055-30.514-13.055-23.3 0-42.189 18.889-42.189 42.189 0 11.993 5.005 22.818 13.039 30.499l0.016 0.015 348.16 348.16c25.366 25.445 41.049 60.555 41.049 99.328s-15.684 73.883-41.053 99.332l0.004-0.004-348.16 348.16c-7.615 7.631-12.323 18.165-12.323 29.798 0 23.277 18.85 42.151 42.118 42.189l0.004 0z"></path></svg><a href="/economia/">Economía</a></span><span class="Breadcrumb-Text"><svg class="Breadcrumb Breadcrumb-Icon" style="display:inline-block;stroke:currentColor;fill:currentColor" viewBox="0 0 1024 1024"><path d="M323.738 1038.541c0.004 0 0.009 0 0.014 0 11.648 0 22.195-4.715 29.836-12.34l-0.001 0.001 348.16-348.16c40.62-40.697 65.738-96.877 65.738-158.925s-25.119-118.228-65.742-158.928l0.003 0.003-348.16-348.16c-7.696-8.051-18.521-13.055-30.514-13.055-23.3 0-42.189 18.889-42.189 42.189 0 11.993 5.005 22.818 13.039 30.499l0.016 0.015 348.16 348.16c25.366 25.445 41.049 60.555 41.049 99.328s-15.684 73.883-41.053 99.332l0.004-0.004-348.16 348.16c-7.615 7.631-12.323 18.165-12.323 29.798 0 23.277 18.85 42.151 42.118 42.189l0.004 0z"></path></svg><a href="/economia/finanzas-personales/">Finanzas Personales</a></span></div></div></span></div><div class="Layout-Divisions pure-u-1"><div class="ArticleHeader ArticleHeader_article"><div class="ArticleHeader-PremiumContainer"><div class="ArticleHeader-Premium">Suscriptores</div></div><h1 class="Title ArticleHeader-Title Title_article">Comprar dólares: ¿cómo están las aguas para invertir en la divisa?</h1><h2 class="ArticleHeader-Hook"><div>Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.</div></h2><div class="ArticleHeader-ContainerSocial"><div class="ArticleHeader-ContainerInfo"><div class="ArticleHeader-ImageContainer"><a href="/autores/daniel-felipe-rodriguez-rincon"><img alt="Daniel Felipe Rodríguez Rincón " class="ArticleHeader-ImageAuthor" height="45" src="https://www.elespectador.com/resizer/LX021D97Sc0V0wfZfVWbzxj-B_Y=/140x140/filters:quality(60):format(jpeg)/s3.amazonaws.com/arc-authors/elespectador/bf4fa90c-f6b4-4348-97e4-580a0db709e2.png" width="45"/></a></div><div class="ArticleHeader-ContainerAuthor"><div class="ArticleHeader-Author"><a href="/autores/daniel-felipe-rodriguez-rincon">Daniel Felipe Rodríguez Rincón </a></div><div class="Datetime ArticleHeader-Date">12 de febrero de 2024 - 07:00 a. m.</div></div></div><div class="SocialMedia"><div class="SocialMedia_share"><a class="SocialMedia_whatsappChanel" href="https://whatsapp.com/channel/0029VZzbXdXLSmbdQGUY8H02" id="Whatsapp-Icon"><svg class="SocialMedia-Icon SocialMedia_whatsapp" style="display:inline-block;stroke:currentColor;fill:currentColor" viewBox="0 0 1024 1024"><path d="M486.911 22.359c-268.314 7.757-487.802 236.829-485.521 505.142 0.912 88.525 24.641 171.119 65.253 242.76l-61.603 224.964c-4.563 15.515 10.039 30.573 26.466 26.922l232.265-58.409c72.554 39.243 155.604 61.147 244.586 60.233 267.858-3.194 491.453-225.877 495.103-493.735 4.107-285.198-229.984-516.094-516.094-507.88zM751.118 705.009c-10.495 29.66-61.603 56.127-86.244 59.777-22.359 3.194-50.195 4.563-80.312-5.019-18.709-5.932-42.438-13.69-73.011-26.922-128.225-54.302-211.731-181.614-217.662-190.284-6.845-8.67-52.020-68.448-52.020-130.507s31.029-94.002 44.719-105.409c65.253-55.214 87.613 6.389 87.613 6.389 10 ...
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/"
#       },
#     "mainEntity": {
#               "@type": "ItemList",
#               "itemListElement": [
#       {
#           "@type": "ListItem",
#           "position": 0,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/dolar/",
#             "name": "Dólar"
#           }
#         },{
#           "@type": "ListItem",
#           "position": 1,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/inversion/",
#             "name": "Inversión"
#           }
#         },{
#           "@type": "ListItem",
#           "position": 2,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/tasas-de-interes/",
#             "name": "Tasas de interés"
#           }
#         },{
#           "@type": "ListItem",
#           "position": 3,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/inflacion-en-colombia/",
#             "name": "Inflación en Colombia"
#           }
#         },{
#           "@type": "ListItem",
#           "position": 4,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/finanzas-personales/",
#             "name": "Finanzas personales"
#           }
#         },{
#           "@type": "ListItem",
#           "position": 5,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/premiumee/",
#             "name": "PremiumEE"
#           }
#         },{
#           "@type": "ListItem",
#           "position": 6,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/invertir-en-dolares/",
#             "name": "invertir en dólares"
#           }
#         },{
#           "@type": "ListItem",
#           "position": 7,
#           "item":
#           {
#             "@type":"WebPage",
#             "@id": "https://www.elespectador.com/tags/inversionistas/",
#             "name": "Inversionistas"
#           }
#         }
#     ]},
#       "headline": "Comprar dólares: ¿cómo están las aguas para invertir en la divisa?",
#       "alternativeHeadline": "Comprar dólares: ¿cómo están las aguas para invertir en la divisa?",
#       "articleSection": "Finanzas personales",
#       "url": "https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/",
#       "image": ["https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg"],
#       "datePublished": "2024-02-12T07:00:00",
#       "dateModified": "2024-02-12T07:00:01",
#       "author": [
#          {
#                       "@type": "Person",
#                       "name":"Daniel Felipe Rodríguez Rincón "
#                       ,"url":"https://www.elespectador.com/autores/daniel-felipe-rodriguez-rincon/"
#                     }
#       ],
#        "publisher": {
#         "@id": "https://www.elespectador.com",
#         "@type": "NewsMediaOrganization",
#         "name": "El Espectador",
#         "logo": {
#           "@type": "ImageObject",
#           "url": "https://www.elespectador.com/pf/resources/images/favicons/favicon-EE-152.png?d=823"
#         }
#       },
#       "description": "Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos.",
#       "isAccessibleForFree": false
#       ,"articleBody":"Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas. Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024."
#
#         ,"hasPart": {
#           "@type": "WebPageElement",
#           "isAccessibleForFree": false,
#           "cssSelector": ".paywall"
#         },
#         "isPartOf":{
#           "@type": ["CreativeWork","Product"],
#           "name": "Suscripción Digital",
#           "description": "Apreciado lector, te invitamos a suscribirte a uno de nuestros planes para continuar disfrutando de este contenido exclusivo.",
#           "sku": "https://www.elespectador.com/suscripcion-digital/",
#           "brand": {
#             "@type": "Brand",
#             "name": "El Espectador"
#           },
#           "offers":{
#             "@type": "Offer",
#             "url": "https://www.elespectador.com/suscripcion-digital/"
#           }
#         }
#
#     }</script><script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@type": "DataFeed",
#     "name": "Comprar dólares: ¿cómo están las aguas para invertir en la divisa?",
#     "description": "Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos.",
#     "creator": {
#       "@type": "Organization",
#       "name": "El Espectador",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "/pf/resources/images/favicons/favicon-EE-152.png?d=823"
#       }
#     },
#     "dataFeedElement": [
#       {
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "Dólar"
#             }
#           },{
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "Inversión"
#             }
#           },{
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "Tasas de interés"
#             }
#           },{
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "Inflación en Colombia"
#             }
#           },{
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "Finanzas personales"
#             }
#           },{
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "PremiumEE, etiqueta para manejo de contenido exclusivo"
#             }
#           },{
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "invertir en dólares"
#             }
#           },{
#             "@type": "DataFeedItem",
#             "item":
#             {
#               "@type":"Thing",
#               "name": "Inversionistas"
#             }
#           }
#     ]
#   }</script><section><!--$--><script type="application/ld+json">{
#     "@context": "http://schema.org",
#     "@type": "ImageObject",
#     "author": "Foto: Getty Images - Yagi Studio",
#     "url": "https://cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg",
#     "datePublished": "2021-08-27T00:21:55Z",
#     "description": "En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images",
#     "height": 531,
#     "width": 800
#   }</script><div class="ImageArticle-Container"><div class="ImageArticle-ImageFrame"><picture><source class="ImageArticle-Image" media="(max-width:425px)" srcset="https://www.elespectador.com/resizer/3CKpccCRlF6vS1UUInIKcCBPc0s=/393x261/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg"/><source class="ImageArticle-Image" media="(max-width:600px)" srcset="https://www.elespectador.com/resizer/ahiZg9HZM-aAB2I-roOkoBbH8e8=/568x378/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg"/><source class="ImageArticle-Image" media="(max-width:1199px)" srcset="https://www.elespectador.com/resizer/SNbovcj8sRIRm9IaT-v-o9mvTYw=/1110x739/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg"/><source class="ImageArticle-Image" media="(min-width:1200px)" srcset="https://www.elespectador.com/resizer/csnE3Xh3YSOOPgZPLyU7OKx9INs=/920x613/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg"/><img alt="En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images" class="ImageArticle-Image" height="531" src="https://www.elespectador.com/resizer/csnE3Xh3YSOOPgZPLyU7OKx9INs=/920x613/filters:quality(60):format(jpeg)/cloudfront-us-east-1.images.arcpublishing.com/elespectador/X4TI25ETKZFMFFPYO6QIXH6KII.jpg" width="800"/></picture></div><div class="ImageArticle-ContainerText"><div class="ImageArticle-Description">En lo corrido de 2024, la divisa ha transcurrido entre mínimos de $3.889 y máximos de $3.975. Imagen de referencia.  / Getty Images</div><div class="ImageArticle-Author">Foto: Getty Images - Yagi Studio</div></div></div><!--/$--><p class="font--secondary">Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.</p><p class="font--secondary">Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024.</p><div class="Article-Widget Article-Widget_related"><div class="lazyload-placeholder"></div></div><div class="exclusive_validation"> </div></section><!--$--><div data-google-interstitial="false"><div class="pianoYellowBannerArticle PianoContainer PianoContainer_article" id="pianoSubContainer"></div></div><!--/$--><div class="ACredit_article ACredit_signDivition ACredit_sign"><div class="ACredit"><div class="ACredit-ImageFrame"><img alt="Daniel Felipe Rodríguez Rincón " class="ACredit-Image" height="58" src="https://www.elespectador.com/resizer/LX021D97Sc0V0wfZfVWbzxj-B_Y=/140x140/filters:quality(60):format(jpeg)/s3.amazonaws.com/arc-authors/elespectador/bf4fa90c-f6b4-4348-97e4-580a0db709e2.png" width="58"/></div><div class="ACredit-Info"><h3 class="ACredit-Author"><a href="/autores/daniel-felipe-rodriguez-rincon/">Por Daniel Felipe Rodríguez Rincón </a></h3><div class="ACredit-Hook">Comunicador Social y Periodista. Desde 2017, se ha desempeñado en diferentes medios de comunicación colombianos.<span class="ACredit-SocialMedia"><a href="https://twitter.com/@DanfeRodriguez" rel="noreferrer" target="_blank"><svg style="display:inline-block;stroke:currentColor;fill:currentColor" viewBox="0 0 1024 1024"><path d="M155.566 176.768l276.5 369.906-278.22 300.558h62.753l243.544-263.31 196.846 263.31h213.176l-292.261-390.526 259.304-279.938h-62.753l-224.345 242.392-181.373-242.392h-213.176zM247.821 222.896h97.994l432.362 578.209h-97.994l-432.362-578.209z"></path></svg>@DanfeRodriguez</a></span><span class="ACredit-SocialMedia"><a href="mailto:drodriguez@elespectador.com"><svg style="display:inline-block;stroke:currentColor;fill:curr ...

# %%
subtitle = soup1.find_all('meta')[1]['content']
subtitle
# Out:
# 'Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos.'

# %%
type(soup1)
# Out:
# bs4.BeautifulSoup

# %%
linkUrl = soup1.find_all('link')[2]['href']
linkUrl
# Out:
# 'https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/?outputType=amp'

# %%
author= soup1.find('h3', class_="ACredit-Author").get_text()
author
# Out:
# 'Por Daniel Felipe Rodríguez Rincón '

# %%
date = soup1.find('div', class_="Datetime ArticleHeader-Date").get_text()
date
# Out:
# '12 de febrero de 2024 - 07:00 a. m.'

# %%
# Collecting all data into a string
completeArticle = title + '\n' + 'Por: '+ author + '\n' + subtitle + '\n' + linkUrl + '\n' + date + '\n' + articleString
print(f"{completeArticle : >20}")
#print(f"{'Left Aligned Text' : <20}")
# Out:
# Comprar dólares: ¿cómo están las aguas para invertir en la divisa? | Noticias Colombia | EL ESPECTADOR
# Por: Por Daniel Felipe Rodríguez Rincón
# Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos.
# https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/?outputType=amp
# 12 de febrero de 2024 - 07:00 a. m.
#
#
# Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.
#
# Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.
#
# Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024.
#
# <b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/finanzas-personales/es-buen-momento-para-endeudarse-asi-estan-los-creditos-en-2024-noticias-colombia/" target="_blank"><i><b>¿Es buen momento para endeudarse?: así está el panorama del crédito en 2024</b></i></a>
#
# Al mirar en el retrovisor, lejos ha quedado ya aquel temido noviembre de 2022, cuando el dólar subió más allá del umbral de los $5.000, desatando un frenesí de compra en el que muchas personas se agolparon en las taquillas de las casas de cambio por el temor a que el billete verde se siguiera encumbrando hasta aplastar al peso colombiano y, de paso, la capacidad adquisitiva de miles de consumidores. Hoy, muchos se sonrojan al recordar este episodio.
#
# Pero allá, donde el horizonte se pierde, está un 2014 donde el dólar valía $2.000. Días que no volverán, especialmente tras una pandemia, una espiral inflacionaria generalizada y una desaceleración económica global.
#
# Sin ir más lejos, de un año hacia acá la tasa de cambio del dólar ha caído más o menos unos $1.000 y en lo corrido de 2024 la divisa ha transcurrido entre mínimos de <b>$3.889 y máximos de $3.975 </b>en su Tasa Representativa del Mercado (TRM).
#
# <iframe title="Tasa Representativa del Mercado en 2023" aria-label="Interactive line chart" id="datawrapper-chart-b0ujw" src="https://datawrapper.dwcdn.net/b0ujw/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();
# </script>
#
#
# Varios analistas coinciden en que el arranque del año ha estado marcado por una inusitada estabilidad en la moneda estadounidense, después de un par de años donde nos acostumbró a la volatilidad.
#
# “Los movimientos en lo corrido de 2024 lo que están haciendo es consolidar la tasa de cambio en unos niveles más estables y sostenibles y se espera que esto siga así”, explica <b>Sergio Olarte</b>, economista principal de Scotiabank Colpatria.
#
# <b>Lea también: </b><a href="https://www.elespectador.com/economia/super-bowl-publicidad-y-economia-como-el-evento-es-una-maquina-de-hacer-dinero/" target="_blank"><b>Super Bowl, publicidad y economía: cómo el evento es una máquina de hacer dinero</b></a>
#
# No obstante, Olarte advierte que la volatilidad de la moneda se incrementó en las últimas semanas, con cambios de $20 de un día para otro a cambios de $50 y hasta $100. Esto, entre otras cosas, por recientes comentarios de firmas calificadoras de riesgo (como S&amp;P Global Ratings) acerca de la economía colombiana.
#
# <iframe title="TRM en 2024" aria-label="Interactive line chart" id="datawrapper-chart-mm185" src="https://datawrapper.dwcdn.net/mm185/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();
# </script>
#
#
# Dentro de las proyecciones para la tasa de cambio, los analistas estiman un dólar más barato al cierre del primer trimestre del año. Un factor a tener en cuenta si está planeando comprar divisas ahora. Sin embargo, las propias proyecciones del Gobierno en su Plan Financiero establecen que la tasa de cambio se ubicará por encima de los $4.000 para terminar 2024.
#
# <b>Lea también: </b><a href="https://www.elespectador.com/economia/las-alarmas-en-el-plan-financiero-2024-del-gobierno-segun-anif-noticias-colombia/" target="_blank"><b>Las alarmas que enciende el Plan Financiero 2024 del Gobierno</b></a>
#
# ¿Es buen momento para invertir en dólares?
#
# “El dólar puede bajar un poco más al cierre del primer trimestre e, incluso, más en el segundo trimestre del año, atendiendo a que la inflación está controlada en Estados Unidos, se acerca a la meta del 2 %, y la Reserva Federal disminuirá su tasa de interés este año. Esto hará que el mercado estadounidense sea menos atractivo para invertir y los inversionistas buscarán economías emergentes, como la nuestra, donde los intereses han venido bajando, pero siguen siendo altos para la región”, explica <b>Sebastián Chacón</b>, director de la Escuela de Negocios y Desarrollo Internacional del Politécnico Grancolombiano.
#
# En la misma línea, <b>Felipe Campos</b>, gerente de Estrategia e Inversión de Alianza Fiduciaria, explica que monedas como las de Colombia o México han resistido bien los incrementos en el dólar a comparación del resto de la región, de ahí que permanezcan con relativa poca volatilidad.
#
# Para el experto en inversiones, el dólar tendría presiones bajistas en el corto plazo, por ejemplo, el dato de inflación en Estados Unidos para enero de 2024 (que se conocerá en los próximos días).
#
# <b>Lea también: </b><a href="https://www.elespectador.com/economia/armando-benedetti-a-la-fao-le-sirve-a-colombia-tener-nuevo-embajador-en-la-organizacion/" target="_blank"><b>Benedetti a la FAO: ¿le sirve a Colombia tener nuevo embajador en la organización?</b></a>
#
# “Y si el dólar baja más, nos gustaría comprarlo en ese momento porque el resto del año va a ser movido. Se vienen los trámites de las reformas en Colombia, antes de junio, y luego las elecciones en Estados Unidos”, indica Campos.
#
# El primer consejo al invertir es que se debe hacerlo cuando esa acción, esa criptomoneda, ese gramo de oro o el activo que le llame la atención (el dólar en este caso) esté bajando de precio.
#
# Así las cosas, puede que sea muy pronto para apostarle a una divisa que, como indican los pronósticos, podría ser más barata al cabo de algunas semanas. Si tiene un viaje al exterior o una compra internacional en mente, quizá le convenga esperar unas semanas para comprar dólares.
#
# Dicho esto, siempre es clave mencionar que el mundo gira y gira y estas proyecciones bien pueden verse alteradas de un día para otro debido a eventos globales que le pegan a una serie de factores económicos (hablamos de eventos como guerras, pandemias, inestabilidad política...). No hay una respuesta única, certera y a prueba de coyunturas acerca del precio del dólar, en últimas.
#
# <b>¿El dólar ya no es buen negocio?</b>
#
# Por décadas, la compra de dólares era el vehículo al cual se subían quienes querían ganarse unos pesos aprovechando la tasa de cambio, resguardarse de la inflación confiando en una moneda más fuerte que la nuestra o construir un patrimonio sin aventurarse en las turbulencias de la bolsa de valores.
#
# Esto ha venido cambiando y la compra de dólares en sí misma (es decir, cambiar pesos por su equivalente en divisa americana) ha perdido algo de su atractivo para 2024.
#
# “En 2022, la compra de dólares enriqueció a muchos. La divisa estuvo en niveles bajos durante una parte del año, hasta que la incertidumbre económica -un factor clave aquí- fue llevándola a precios tan altos como los $5.200. Ahora, el escenario es bastante distinto: nuestra inflación viene bajando, la Fed ha dicho que bajará tasas en algún momento del año y, en general, hay un mercado de certidumbre donde no se esperan movimientos bruscos de la tasa de cambio”, asevera <b>Henry Amorocho</b>, profesor de Hacienda Pública y Presupuesto de la Universidad del Rosario.
#
# <b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/macroeconomia/la-inflacion-arranca-2024-bajando-en-enero-y-acumula-10-meses-de-descensos-continuos/" target="_blank"><i><b>La inflación arranca 2024 bajando y acumula 10 meses de descensos continuos</b></i></a>
#
# Dicen los analistas que los dólares (y cualquier divisa) son buen negocio cuando hay grandes “espacios cambiarios”, es decir, amplias distancias entre el precio actual del dólar y el que tendría en el futuro. Lo cierto es que esta franja, a día de hoy, es pequeña, así como las ganancias que tendría un inversionista.
#
# Por ejemplo, la mayoría de los analistas económicos consultados por el Banco de la República en enero pasado previó una Tasa Representativa del Mercado (TRM) entre los <b>$3.839 y $3.939</b> durante 2024. Así mismo, los más recientes pronósticos de Fedesarrollo indican que la TRM no será mayor a <b>$4.025</b> a diciembre de 2024.
#
# Con un dólar a <b>$3.922</b> al cierre del pasado 9 de febrero, la eventual valorización de una inversión en dólares en 2024 -bajo un escenario sin sorpresas- podría no ser suficientemente jugosa para algunos inversionistas.
#
# “Creemos que el dólar está cambiando de tendencia después de 12 años. Ya no consideramos que vaya a tener un gran valor en el largo plazo, pero sigue siendo un activo importante para diversificar, porque si a Colombia le va mal, al dólar le va bien. Entonces siempre se debe tener algo en dólar”, aconseja el gerente de Estrategia e Inversión de Alianza Fiduciaria.
#
# En esto coincide <b>Michael Ortegón</b>, decano de la Facultad de Ciencias Económicas y Administrativas de UNINPAHU, quien explica que la compra de dólares solo debe hacerse para hacer inversiones que agregarán más valor en el largo plazo.
#
# “El dólar no se debe usar como medio de cambio o para “ahorrarlo” en cuentas de ahorro que no ganan ningún interés por estar depositados. En cualquier caso, la moneda estadounidense estará por encima del peso colombiano, pero eso no implica que sea buena idea comprar dólares”, agrega el académico.
#
# Se suele recomendar que entre un 20 % a un 30 % de los ahorros de una persona estén tasados en una moneda extranjera (como el dólar), ya sea en algún fondo de inversión o en cuentas tasadas en divisas, las cuales son ofrecidas por la mayoría de los bancos en Colombia. Eso sí, estos productos están destinados a depósitos por encima de los $30 millones.
#
# <b>Activos en dólares</b>
#
# Si apostarles a los billetes verdes (por sí solos) no es tan recomendable en este momento, el panorama es muy distinto para los activos tasados en dólares, tales como las acciones, los bonos del Tesoro o los inmuebles.
#
# “El activo en dólares que mejor le está yendo son las acciones de empresas estadounidenses, que están disparadas y están teniendo mucho mejor retorno que el resto de acciones en el mundo, gracias a los resultados de las empresas de tecnología”, afirma Felipe Campos.
#
# En esto coincide el decano de UNINPAHU, quien resalta que “ciertos activos valuados en dólares muestran un desempeño positivo, destacándose las acciones tecnológicas de empresas líderes como Apple, Microsoft y Amazon. Además, el mercado inmobiliario se mantiene sólido (debido a las tasas de interés altas), con propiedades residenciales y comerciales conservando su valor; mientras que el oro, considerado a menudo como un refugio seguro, ha experimentado un aumento en su precio”.
#
# <b>Puede interesarle:</b><a href="https://www.elespectador.com/economia/la-reserva-federal-bajara-las-tasas-de-interes-en-estados-unidos/" target="_blank"><b> </b><i><b>¿Tasas de interés más bajas en EE.UU.?: sí, pero no tan rápido</b></i></a>
#
# Finalmente, Olarte, el economista principal de Scotiabank Colpatria destaca que “se podría pensar en acciones en Estados Unidos que podrían seguir valorizándose o alguna inversión inmobiliaria que salga más o menos rentable (…). Los activos que están teniendo un buen momento son alguna parte de las acciones en Estados Unidos, porque se espera que las tasas de interés bajen y eso puede ayudar a que la parte bursátil del mundo se mejore”.
#
# Tenga en cuenta que si va a invertir en activos de alto riesgo, como la renta variable (acciones), lo mejor es asesorarse con profesionales. En materia de dólar, el mejor consejo en este momento es actuar con prudencia. Lo que indican los analistas es que parece no ser el mejor momento para vender casa, carro o invertir sus ahorros en una moneda que, parece, podría no dar los mejores resultados.
#
# 💰📈💱 <b>¿Ya te enteraste de las últimas noticias </b><a href="https://www.elespectador.com/economia"><b>económicas</b></a><b>? </b>Te invitamos a verlas en <a href="https://www.elespectador.com/economia/">El Espectador</a>.

# %%
type(completeArticle)
# Out:
# str

# %%
# We finally have the objective data with all the features as desired
completeArticle
# Out:
# 'Comprar dólares: ¿cómo están las aguas para invertir en la divisa? | Noticias Colombia | EL ESPECTADOR\nPor: Por Daniel Felipe Rodríguez Rincón \nUn dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos.\nhttps://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/?outputType=amp\n12 de febrero de 2024 - 07:00 a. m.\n\n\nInvertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.\n\nComprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.\n\nSiguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024.\n\n<b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/finanzas-personales/es-buen-momento-para-endeudarse-asi-estan-los-creditos-en-2024-noticias-colombia/" target="_blank"><i><b>¿Es buen momento para endeudarse?: así está el panorama del crédito en 2024</b></i></a>\n\nAl mirar en el retrovisor, lejos ha quedado ya aquel temido noviembre de 2022, cuando el dólar subió más allá del umbral de los $5.000, desatando un frenesí de compra en el que muchas personas se agolparon en las taquillas de las casas de cambio por el temor a que el billete verde se siguiera encumbrando hasta aplastar al peso colombiano y, de paso, la capacidad adquisitiva de miles de consumidores. Hoy, muchos se sonrojan al recordar este episodio.\n\nPero allá, donde el horizonte se pierde, está un 2014 donde el dólar valía $2.000. Días que no volverán, especialmente tras una pandemia, una espiral inflacionaria generalizada y una desaceleración económica global.\n\nSin ir más lejos, de un año hacia acá la tasa de cambio del dólar ha caído más o menos unos $1.000 y en lo corrido de 2024 la divisa ha transcurrido entre mínimos de <b>$3.889 y máximos de $3.975 </b>en su Tasa Representativa del Mercado (TRM).\n\n<iframe title="Tasa Representativa del Mercado en 2023" aria-label="Interactive line chart" id="datawrapper-chart-b0ujw" src="https://datawrapper.dwcdn.net/b0ujw/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();\r\n</script>\r\n\n\nVarios analistas coinciden en que el arranque del año ha estado marcado por una inusitada estabilidad en la moneda estadounidense, después de un par de años donde nos acostumbró a la volatilidad.\n\n“Los movimientos en lo corrido de 2024 lo que están haciendo es consolidar la tasa de cambio en unos niveles más estables y sostenibles y se espera que esto siga así”, explica <b>Sergio Olarte</b>, economista principal de Scotiabank Colpatria.\n\n<b>Lea también: </b><a href="https://www.elespectador.com/economia/super-bowl-publicidad-y-economia-como-el-evento-es-una-maquina-de-hacer-dinero/" target="_blank"><b>Super Bowl, publicidad y economía: cómo el evento es una máquina de hacer dinero</b></a>\n\nNo obstante, Olarte advierte que la volatilidad de la moneda se incrementó en las últimas semanas, con cambios de $20 de un día para otro a cambios de $50 y hasta $100. Esto, entre otras cosas, por recientes comentarios de firmas calificadoras de riesgo (como S&amp;P Global Ratings) ace ...

# %% [markdown]
# It's a little bit tricky to scrape dynamic web pages, however just using basic tools it is possible to hit that goal. Analyzing html and javascript is a key part of the procedure, also to become readable the javascript part where our objective data is embedded.

# %%
pip install telepot
# Out:
# Collecting telepot
#   Downloading telepot-12.7.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from telepot) (2.0.7)
# Requirement already satisfied: aiohttp>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from telepot) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.0.0->telepot) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.0.0->telepot) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.0.0->telepot) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.0.0->telepot) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.0.0->telepot) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.0.0->telepot) (4.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp>=3.0.0->telepot) (3.6)
# Building wheels for collected packages: telepot
#   Building wheel for telepot (setup.py) ... done
#   Created wheel for telepot: filename=telepot-12.7-py3-none-any.whl size=57939 sha256=def47535da12cade1ffab4af66968045208da4ad55853e3a946ca3dc9fd0a076
#   Stored in directory: /root/.cache/pip/wheels/9f/9a/92/2e34a093e40a09338847e54dc9fcaab4ce01a59ba17c784c6c
# Successfully built telepot
# Installing collected packages: telepot
# Successfully installed telepot-12.7

# %%
import telepot

# %%
token = '5541258900:AAE0PhrKqTjHMWk3-ZdePgzrgRJiB3hv5CI' # telegram token
receiver_id = 582395721 # https://api.telegram.org/bot<TOKEN>/getUpdates


bot = telepot.Bot(token)

if len(completeArticle) > 4096:
    for x in range(0, len(completeArticle), 4096):
        bot.sendMessage(receiver_id, completeArticle[x:x+4096])
else:
    bot.sendMessage(receiver_id, completeArticle)

#if len(completeArticle) > 4096:
    #for x in range(0, len(completeArticle), 4096):
        #bot.send_message(message.chat.id, completeArticle[x:x+4096])
    #else:
        #bot.send_message(message.chat.id, completeArticle)

#bot.sendMessage(receiver_id, completeArticle) # send a activation message to telegram receiver id

#bot.sendPhoto(receiver_id, photo=open('test_img.png', 'rb')) # send message to telegram

# %%
print(f"{completeArticle : >20}")
# Out:
# Comprar dólares: ¿cómo están las aguas para invertir en la divisa? | Noticias Colombia | EL ESPECTADOR
# Por: Por Daniel Felipe Rodríguez Rincón
# Un dólar que todavía no llega a los $4.000 aviva la compra de divisas. ¿Qué tan buen negocio es? Le contamos.
# https://www.elespectador.com/economia/finanzas-personales/comprar-dolares-como-estan-las-aguas-para-invertir-en-la-divisa-noticias-colombia/?outputType=amp
# 12 de febrero de 2024 - 07:00 a. m.
#
#
# Invertir en dólares se suele percibir como una apuesta sobre seguro, una vía para hacerle el quite a la inflación y hasta una forma de ganarse unos pesos sin mucho esfuerzo. ¿Cómo se ve el camino para esta divisa en 2024? Esto dicen los analistas.
#
# Comprar barato y vender caro. Una estrategia clásica en el mundo de los negocios que, de paso, aplica también para las inversiones en divisas.
#
# Siguiendo esta línea, vale preguntarse: ¿estamos ante un dólar bajo que luego se pueda vender a un precio mayor? Para responder a esta pregunta, primero hay que aclarar qué es exactamente un dólar barato y hasta dónde podría escalar la tasa de cambio en 2024.
#
# <b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/finanzas-personales/es-buen-momento-para-endeudarse-asi-estan-los-creditos-en-2024-noticias-colombia/" target="_blank"><i><b>¿Es buen momento para endeudarse?: así está el panorama del crédito en 2024</b></i></a>
#
# Al mirar en el retrovisor, lejos ha quedado ya aquel temido noviembre de 2022, cuando el dólar subió más allá del umbral de los $5.000, desatando un frenesí de compra en el que muchas personas se agolparon en las taquillas de las casas de cambio por el temor a que el billete verde se siguiera encumbrando hasta aplastar al peso colombiano y, de paso, la capacidad adquisitiva de miles de consumidores. Hoy, muchos se sonrojan al recordar este episodio.
#
# Pero allá, donde el horizonte se pierde, está un 2014 donde el dólar valía $2.000. Días que no volverán, especialmente tras una pandemia, una espiral inflacionaria generalizada y una desaceleración económica global.
#
# Sin ir más lejos, de un año hacia acá la tasa de cambio del dólar ha caído más o menos unos $1.000 y en lo corrido de 2024 la divisa ha transcurrido entre mínimos de <b>$3.889 y máximos de $3.975 </b>en su Tasa Representativa del Mercado (TRM).
#
# <iframe title="Tasa Representativa del Mercado en 2023" aria-label="Interactive line chart" id="datawrapper-chart-b0ujw" src="https://datawrapper.dwcdn.net/b0ujw/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();
# </script>
#
#
# Varios analistas coinciden en que el arranque del año ha estado marcado por una inusitada estabilidad en la moneda estadounidense, después de un par de años donde nos acostumbró a la volatilidad.
#
# “Los movimientos en lo corrido de 2024 lo que están haciendo es consolidar la tasa de cambio en unos niveles más estables y sostenibles y se espera que esto siga así”, explica <b>Sergio Olarte</b>, economista principal de Scotiabank Colpatria.
#
# <b>Lea también: </b><a href="https://www.elespectador.com/economia/super-bowl-publicidad-y-economia-como-el-evento-es-una-maquina-de-hacer-dinero/" target="_blank"><b>Super Bowl, publicidad y economía: cómo el evento es una máquina de hacer dinero</b></a>
#
# No obstante, Olarte advierte que la volatilidad de la moneda se incrementó en las últimas semanas, con cambios de $20 de un día para otro a cambios de $50 y hasta $100. Esto, entre otras cosas, por recientes comentarios de firmas calificadoras de riesgo (como S&amp;P Global Ratings) acerca de la economía colombiana.
#
# <iframe title="TRM en 2024" aria-label="Interactive line chart" id="datawrapper-chart-mm185" src="https://datawrapper.dwcdn.net/mm185/2/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="400" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",(function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r=0;r<e.length;r++)if(e[r].contentWindow===a.source){var i=a.data["datawrapper-height"][t]+"px";e[r].style.height=i}}}))}();
# </script>
#
#
# Dentro de las proyecciones para la tasa de cambio, los analistas estiman un dólar más barato al cierre del primer trimestre del año. Un factor a tener en cuenta si está planeando comprar divisas ahora. Sin embargo, las propias proyecciones del Gobierno en su Plan Financiero establecen que la tasa de cambio se ubicará por encima de los $4.000 para terminar 2024.
#
# <b>Lea también: </b><a href="https://www.elespectador.com/economia/las-alarmas-en-el-plan-financiero-2024-del-gobierno-segun-anif-noticias-colombia/" target="_blank"><b>Las alarmas que enciende el Plan Financiero 2024 del Gobierno</b></a>
#
# ¿Es buen momento para invertir en dólares?
#
# “El dólar puede bajar un poco más al cierre del primer trimestre e, incluso, más en el segundo trimestre del año, atendiendo a que la inflación está controlada en Estados Unidos, se acerca a la meta del 2 %, y la Reserva Federal disminuirá su tasa de interés este año. Esto hará que el mercado estadounidense sea menos atractivo para invertir y los inversionistas buscarán economías emergentes, como la nuestra, donde los intereses han venido bajando, pero siguen siendo altos para la región”, explica <b>Sebastián Chacón</b>, director de la Escuela de Negocios y Desarrollo Internacional del Politécnico Grancolombiano.
#
# En la misma línea, <b>Felipe Campos</b>, gerente de Estrategia e Inversión de Alianza Fiduciaria, explica que monedas como las de Colombia o México han resistido bien los incrementos en el dólar a comparación del resto de la región, de ahí que permanezcan con relativa poca volatilidad.
#
# Para el experto en inversiones, el dólar tendría presiones bajistas en el corto plazo, por ejemplo, el dato de inflación en Estados Unidos para enero de 2024 (que se conocerá en los próximos días).
#
# <b>Lea también: </b><a href="https://www.elespectador.com/economia/armando-benedetti-a-la-fao-le-sirve-a-colombia-tener-nuevo-embajador-en-la-organizacion/" target="_blank"><b>Benedetti a la FAO: ¿le sirve a Colombia tener nuevo embajador en la organización?</b></a>
#
# “Y si el dólar baja más, nos gustaría comprarlo en ese momento porque el resto del año va a ser movido. Se vienen los trámites de las reformas en Colombia, antes de junio, y luego las elecciones en Estados Unidos”, indica Campos.
#
# El primer consejo al invertir es que se debe hacerlo cuando esa acción, esa criptomoneda, ese gramo de oro o el activo que le llame la atención (el dólar en este caso) esté bajando de precio.
#
# Así las cosas, puede que sea muy pronto para apostarle a una divisa que, como indican los pronósticos, podría ser más barata al cabo de algunas semanas. Si tiene un viaje al exterior o una compra internacional en mente, quizá le convenga esperar unas semanas para comprar dólares.
#
# Dicho esto, siempre es clave mencionar que el mundo gira y gira y estas proyecciones bien pueden verse alteradas de un día para otro debido a eventos globales que le pegan a una serie de factores económicos (hablamos de eventos como guerras, pandemias, inestabilidad política...). No hay una respuesta única, certera y a prueba de coyunturas acerca del precio del dólar, en últimas.
#
# <b>¿El dólar ya no es buen negocio?</b>
#
# Por décadas, la compra de dólares era el vehículo al cual se subían quienes querían ganarse unos pesos aprovechando la tasa de cambio, resguardarse de la inflación confiando en una moneda más fuerte que la nuestra o construir un patrimonio sin aventurarse en las turbulencias de la bolsa de valores.
#
# Esto ha venido cambiando y la compra de dólares en sí misma (es decir, cambiar pesos por su equivalente en divisa americana) ha perdido algo de su atractivo para 2024.
#
# “En 2022, la compra de dólares enriqueció a muchos. La divisa estuvo en niveles bajos durante una parte del año, hasta que la incertidumbre económica -un factor clave aquí- fue llevándola a precios tan altos como los $5.200. Ahora, el escenario es bastante distinto: nuestra inflación viene bajando, la Fed ha dicho que bajará tasas en algún momento del año y, en general, hay un mercado de certidumbre donde no se esperan movimientos bruscos de la tasa de cambio”, asevera <b>Henry Amorocho</b>, profesor de Hacienda Pública y Presupuesto de la Universidad del Rosario.
#
# <b>Puede interesarle: </b><a href="https://www.elespectador.com/economia/macroeconomia/la-inflacion-arranca-2024-bajando-en-enero-y-acumula-10-meses-de-descensos-continuos/" target="_blank"><i><b>La inflación arranca 2024 bajando y acumula 10 meses de descensos continuos</b></i></a>
#
# Dicen los analistas que los dólares (y cualquier divisa) son buen negocio cuando hay grandes “espacios cambiarios”, es decir, amplias distancias entre el precio actual del dólar y el que tendría en el futuro. Lo cierto es que esta franja, a día de hoy, es pequeña, así como las ganancias que tendría un inversionista.
#
# Por ejemplo, la mayoría de los analistas económicos consultados por el Banco de la República en enero pasado previó una Tasa Representativa del Mercado (TRM) entre los <b>$3.839 y $3.939</b> durante 2024. Así mismo, los más recientes pronósticos de Fedesarrollo indican que la TRM no será mayor a <b>$4.025</b> a diciembre de 2024.
#
# Con un dólar a <b>$3.922</b> al cierre del pasado 9 de febrero, la eventual valorización de una inversión en dólares en 2024 -bajo un escenario sin sorpresas- podría no ser suficientemente jugosa para algunos inversionistas.
#
# “Creemos que el dólar está cambiando de tendencia después de 12 años. Ya no consideramos que vaya a tener un gran valor en el largo plazo, pero sigue siendo un activo importante para diversificar, porque si a Colombia le va mal, al dólar le va bien. Entonces siempre se debe tener algo en dólar”, aconseja el gerente de Estrategia e Inversión de Alianza Fiduciaria.
#
# En esto coincide <b>Michael Ortegón</b>, decano de la Facultad de Ciencias Económicas y Administrativas de UNINPAHU, quien explica que la compra de dólares solo debe hacerse para hacer inversiones que agregarán más valor en el largo plazo.
#
# “El dólar no se debe usar como medio de cambio o para “ahorrarlo” en cuentas de ahorro que no ganan ningún interés por estar depositados. En cualquier caso, la moneda estadounidense estará por encima del peso colombiano, pero eso no implica que sea buena idea comprar dólares”, agrega el académico.
#
# Se suele recomendar que entre un 20 % a un 30 % de los ahorros de una persona estén tasados en una moneda extranjera (como el dólar), ya sea en algún fondo de inversión o en cuentas tasadas en divisas, las cuales son ofrecidas por la mayoría de los bancos en Colombia. Eso sí, estos productos están destinados a depósitos por encima de los $30 millones.
#
# <b>Activos en dólares</b>
#
# Si apostarles a los billetes verdes (por sí solos) no es tan recomendable en este momento, el panorama es muy distinto para los activos tasados en dólares, tales como las acciones, los bonos del Tesoro o los inmuebles.
#
# “El activo en dólares que mejor le está yendo son las acciones de empresas estadounidenses, que están disparadas y están teniendo mucho mejor retorno que el resto de acciones en el mundo, gracias a los resultados de las empresas de tecnología”, afirma Felipe Campos.
#
# En esto coincide el decano de UNINPAHU, quien resalta que “ciertos activos valuados en dólares muestran un desempeño positivo, destacándose las acciones tecnológicas de empresas líderes como Apple, Microsoft y Amazon. Además, el mercado inmobiliario se mantiene sólido (debido a las tasas de interés altas), con propiedades residenciales y comerciales conservando su valor; mientras que el oro, considerado a menudo como un refugio seguro, ha experimentado un aumento en su precio”.
#
# <b>Puede interesarle:</b><a href="https://www.elespectador.com/economia/la-reserva-federal-bajara-las-tasas-de-interes-en-estados-unidos/" target="_blank"><b> </b><i><b>¿Tasas de interés más bajas en EE.UU.?: sí, pero no tan rápido</b></i></a>
#
# Finalmente, Olarte, el economista principal de Scotiabank Colpatria destaca que “se podría pensar en acciones en Estados Unidos que podrían seguir valorizándose o alguna inversión inmobiliaria que salga más o menos rentable (…). Los activos que están teniendo un buen momento son alguna parte de las acciones en Estados Unidos, porque se espera que las tasas de interés bajen y eso puede ayudar a que la parte bursátil del mundo se mejore”.
#
# Tenga en cuenta que si va a invertir en activos de alto riesgo, como la renta variable (acciones), lo mejor es asesorarse con profesionales. En materia de dólar, el mejor consejo en este momento es actuar con prudencia. Lo que indican los analistas es que parece no ser el mejor momento para vender casa, carro o invertir sus ahorros en una moneda que, parece, podría no dar los mejores resultados.
#
# 💰📈💱 <b>¿Ya te enteraste de las últimas noticias </b><a href="https://www.elespectador.com/economia"><b>económicas</b></a><b>? </b>Te invitamos a verlas en <a href="https://www.elespectador.com/economia/">El Espectador</a>.
